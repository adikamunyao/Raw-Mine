# %% [markdown]
# # <center>Objective 2

# %% [markdown]
# ## How do the organisational structures of global ocean governance bodies shape the management of the ocean economy, and what systemic characteristics contribute to or impede their efficacy?

# %% [markdown]
# <p>The task involves analyzing the data presented in the "Ocean Governance and Ocean Economy Governance Matrix_IGOs” file.</p>
# <p>The objective is to analyze the relationship between various intergovernmental organizations (IGOs) based on their distinct attributes. This involves examining the attributes: spatial and subject matter jurisdictions of these governmental institutions, objectives, strategies, inter-institutional relationships.</p>

# %% [markdown]
# ### Libraries

# %%
# Set up and tools
import re
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import pandas as pd
from nltk.tokenize import sent_tokenize
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
import spacy

# %% [markdown]
# ### Packages

# %%
# Ensure necessary NLTK resources are downloaded
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /home/milo/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /home/milo/nltk_data...
# [nltk_data] Downloading package stopwords to /home/milo/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt_tab to /home/milo/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %% [markdown]
# ### Data

# %%
# File path
file_path = "../raw_data/Ocean Governance and ocean economy governance matrix_IGOs.xlsx"
# Load the dataset
df = pd.read_excel(file_path, header=[0,1])

# %% [markdown]
# ### Data Cleaning

# %%
df.head(2)
# Out:
#                                         Institutions               Year  \
#                                   Unnamed: 0_level_1 Unnamed: 1_level_1
# 0   Intergovernmental Oceanographic Commission (IOC)             1960.0
# 1  Food and Agriculture Organization of the Unite...             1945.0
#
#                Scale                               Jurisdictional Scope  \
#   Unnamed: 2_level_1                               Spatial Jurisdiction
# 0             Global  IOC jurisdiction is global delineated by the b...
# 1             Global  The FAO’s jurisdiction spans a vast array of m...
#
#                                                       \
#                          Subject Matter Jurisdiction
# 0  The IOC's subject matter jurisdiction encompas...
# 1  FAO’s remit includes nutrition, food and agric...
#
#                               Source of Jurisdiction  \
#                                   Unnamed: 5_level_1
# 0  The IOC’s authority is derived from its statut...
# 1  The FAO’s jurisdiction is established through ...
#
#                                   Defined Objectives  \
#                                   Unnamed: 6_level_1
# 0  The objectives of the Intergovernmental Oceano...
# 1  As stated in Article 1 of the Constitution, FA...
#
#                                           Strategies  \
#                                   Unnamed: 7_level_1
# 0  IOC implements its objectives through series o...
# 1   The FAO executes its objectives through a ser...
#
#             Defined inter-institutional Relationship  \
#                                   Unnamed: 8_level_1
# 0  IOC collaborates with UN specialized agencies ...
# 1  As stated in its constitution, the FAO maintai...
#
#                              Practical- Coordination  \
#                                             Vertical
# 0  Vertical coordination within the IOC involves ...
# 1  The FAO’s vertical coordination involves colla...
#
#                                                       \
#                                           Horizontal
# 0  Horizontal coordination within the IOC encompa...
# 1  Horizontal coordination within the FAO involve...
#
#                                                       \
#                                         Horizontal.1
# 0                                                NaN
# 1  https://www.jus.uio.no/english/services/librar...
#
#                                                                              \
#                                      Horizontal.2 Horizontal.3 Horizontal.4
# 0                                             NaN          NaN          NaN
# 1  FAO https://www.fao.org/strategic-framework/en          NaN          NaN
#
#
#   Horizontal.5 Horizontal.6 Horizontal.7 Horizontal.8
# 0          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN

# %%
# Function to rename columns based on provided mapping
def rename_columns(df, column_map):
    # Flatten the column names into a single-level
    df.columns = [column_map.get(col, col) for col in df.columns]
    
    return df

# Define the column mappings (old name -> new name)
column_map = {
    ('Institutions', 'Unnamed: 0_level_1'): 'Institution',
    ('Year', 'Unnamed: 1_level_1'): 'Year',
    ('Scale', 'Unnamed: 2_level_1'): 'Scale',
    ('Jurisdictional Scope', 'Spatial Jurisdiction'): 'Spatial Jurisdiction',
    ('Jurisdictional Scope', 'Subject Matter Jurisdiction'): 'Subject Matter Jurisdiction',
    ('Source of Jurisdiction', 'Unnamed: 5_level_1'): 'Source of Jurisdiction',
    ('Defined Objectives', 'Unnamed: 6_level_1'): 'Defined Objectives',
    ('Strategies', 'Unnamed: 7_level_1'): 'Strategies',
    ('Defined inter-institutional Relationship', 'Unnamed: 8_level_1'): 'Inter-institutional Relationship',
    ('Practical- Coordination', 'Vertical'): 'Practical Vertical Coordination',
    ('Practical- Coordination', 'Horizontal'): 'Practical Horizontal Coordination',
    ('Practical- Coordination', 'Horizontal.1'): 'Horizontal Coordination 1',
    ('Practical- Coordination', 'Horizontal.2'): 'Horizontal Coordination 2',
    ('Practical- Coordination', 'Horizontal.3'): 'Horizontal Coordination 3',
    ('Practical- Coordination', 'Horizontal.4'): 'Horizontal Coordination 4',
    ('Practical- Coordination', 'Horizontal.5'): 'Horizontal Coordination 5',
    ('Practical- Coordination', 'Horizontal.6'): 'Horizontal Coordination 6',
    ('Practical- Coordination', 'Horizontal.7'): 'Horizontal Coordination 7',
    ('Practical- Coordination', 'Horizontal.8'): 'Horizontal Coordination 8'
}

# Apply the renaming function
df = rename_columns(df, column_map)

# %% [markdown]
# ### Data Preprocessing

# %%
# Subseting relevant columns
new_df = df.iloc[:, :11]

# Drop row 48 in place(used in search)
new_df.drop(48, axis=0, inplace=True)

df = new_df.copy()

# %%
df.columns
# Out:
# Index(['Institution', 'Year', 'Scale', 'Spatial Jurisdiction',
#        'Subject Matter Jurisdiction', 'Source of Jurisdiction',
#        'Defined Objectives', 'Strategies', 'Inter-institutional Relationship',
#        'Practical Vertical Coordination', 'Practical Horizontal Coordination'],
#       dtype='object')

# %%
df
# Out:
#                                           Institution    Year   Scale  \
# 0    Intergovernmental Oceanographic Commission (IOC)  1960.0  Global
# 1   Food and Agriculture Organization of the Unite...  1945.0  Global
# 2   Convention on the Intergovernmental Maritime C...  1948.0  Global
# 3   Division for Ocean Affairs and the Law of the ...  1992.0  Global
# 4                          Climate Change Secretariat  1992.0  Global
# 5                      International Seabed Authority  1994.0  Global
# 6         United Nations Environment Programme (UNEP)  1972.0  Global
# 7         United Nations Development Programme (UNDP)  1965.0  Global
# 8   United Nations Conference on Trade and Develop...  1964.0  Global
# 9   United Nations Industrial Development Organiza...  1966.0  Global
# 10            International Labour Organization (ILO)  1919.0  Global
# 11        International Telecommunication Union (ITU)  1865.0  Global
# 12           United Nations Children’s Fund (UNICEF)   1953.0  Global
# 13                   World Health Organization (WHO)   1948.0  Global
# 14  Commissioner for Refugees (UNHCR), and the Off...  1993.0  Global
# 15  United Nations Office for Disaster Risk Reduct...  1999.0  Global
# 16                           UN Global Compact Office  2000.0  Global
# 17          International Atomic Energy Agency (IAEA)  1957.0  Global
# 18            World Meteorological Organization (WMO)  1947.0  Global
# 19  Organisation for Economic Co-operation and Dev...  1961.0  Global
# 20                            World Bank Group (WBG)   1944.0  Global
# 21                  International Monetary Fund (IMF)  1944.0  Global
# 22     International Hydrographic Organization (IHO)   1921.0  Global
# 23   International Council for the Exploration of ...  1902.0  Global
# 24  The Intergovernmental Science-Policy Platform ...  2012.0  Global
# 25                                               IPCC  1988.0  Global
# 26                    World Trade Organization (WTO)   1995.0  Global
# 27  International Organization for Migration (IOM)...  1951.0  Global
# 28  United Nations Office for Project Services (UN...  1994.0  Global
# 29  UN Entity for Gender Equality and the Empowerm...  2010.0  Global
# 30    World Intellectual Property Organisation (WIPO)  1967.0  Global
# 31                         UN Population Fund (UNFPA)  1967.0  Global
# 32  United Nations Human Settlements Programme (UN...  1977.0  Global
# 33                         World Food Programme (WFP)  1961.0  Global
# 34      World Tourism Organization/UN Tourism (UNWTO)  1946.0  Global
# 35  UN Research Institute for Social Development (...  1963.0  Global
# 36  Secretariat of the Basel, Rotterdam and Stockh...  2012.0  Global
# 37  Secretariat of the Convention on Biological Di...  1992.0  Global
# 38  \nSecretariat of the Convention on Internation...  1973.0  Global
# 39  \nSecretariat of the Convention on Migratory S...  1983.0  Global
# 40  International Fund for Agricultural Developmen...  1976.0  Global
# 41                 \nInternational Trade Centre (ITC)  1964.0  Global
# 42  Secretariat of the United Nations Convention t...  1994.0  Global
# 43                    United Nations University (UNU)  1972.0  Global
# 44  Ramsar Convention on Wetlands Secretariat (Ram...  1971.0  Global
# 45          Minamata Convention on Mercury (Minamata)  2013.0  Global
# 46  United Nations Office for Outer Space Affairs ...  1958.0  Global
# 47   United Nations Office on Drugs and Crime (UNODC)  1997.0  Global
#
#                                  Spatial Jurisdiction  \
# 0   IOC jurisdiction is global delineated by the b...
# 1   The FAO’s jurisdiction spans a vast array of m...
# 2   The IMO’s authority spans a global geographica...
# 3   UN DALOS does not have authority over any spec...
# 4   The UNFCCC Secretariat operates globally, supp...
# 5   The international seabed area – the part under...
# 6   The UNEP Secretariat’s authority is global, co...
# 7   UNDP's jurisdiction is global, operating in mo...
# 8   The UNCTAD Secretariat’s authority is not limi...
# 9   UNIDO’s jurisdiction is global, encompassing t...
# 10  ILO's authority is global, covering the labour...
# 11  ITU's geographical area is not confined to a s...
# 12  UNICEF’s authority is global, covering over 19...
# 13  WHO’s jurisdiction is global, encompassing the...
# 14  OHCHR's authority is global, encompassing the ...
# 15  UNDRR's jurisdiction is global, covering all r...
# 16  The UN Global Compact's authority is global, c...
# 17  The IAEA's authority is global, encompassing t...
# 18  WMO's jurisdiction is global, encompassing the...
# 19  The OECD's jurisdiction is global, encompassin...
# 20  The WBG does not have specific authority over ...
# 21  The IMF does not have specific authority over ...
# 22  IHO’s global jurisdiction represents the hydro...
# 23  The International Council for the Exploration ...
# 24  Although no specific spatial coverage stated, ...
# 25  The IPCC's authority is global, covering all r...
# 26  The World Trade Organization (WTO)'s jurisdict...
# 27  IOM's jurisdiction is global, covering all the...
# 28  UNOPS's jurisdiction is global, covering all r...
# 29  UN-Women’s jurisdiction is global, encompassin...
# 30  WIPO does not have a specific authority over o...
# 31  The UNFPA does not have jurisdiction over spec...
# 32  UN-Habitat's jurisdiction is not limited to an...
# 33  The World Food Programme (WFP) is a global org...
# 34  UNWTO's jurisdiction is global, encompassing i...
# 35  UNRISD's work is global in nature as an autono...
# 36  The BRS Secretariat's jurisdiction is global, ...
# 37  The CBD's jurisdiction is based on the princip...
# 38  CITES Secretariat operates globally, with its ...
# 39  The CMS Secretariat's jurisdiction is global, ...
# 40  IFAD's jurisdiction is not limited to any spec...
# 41  ITC's jurisdiction is global, covering all reg...
# 42  The UNCCD Secretariat's jurisdiction is focuse...
# 43  UNU's jurisdiction is not limited to any speci...
# 44  The Ramsar Secretariat's jurisdiction is based...
# 45  The Minamata Convention's jurisdiction is glob...
# 46  UNOOSA's jurisdiction is focused on the explor...
# 47  UNODC's jurisdiction is not limited to a speci...
#
#                           Subject Matter Jurisdiction  \
# 0   The IOC's subject matter jurisdiction encompas...
# 1   FAO’s remit includes nutrition, food and agric...
# 2   The IMO's jurisdiction encompasses a comprehen...
# 3   The UN DOALOS's mandate includes providing inf...
# 4   The UNFCCC Secretariat is responsible for faci...
# 5   The ISA is responsible for administering the i...
# 6   UNEP is responsible for coordinating the envir...
# 7   UNDP’s work is concentrated in three focus are...
# 8   The UNCTAD Secretariat is responsible for prom...
# 9   UNIDO is responsible for the industrial develo...
# 10  The International Labour Organization (ILO) is...
# 11  ITU is responsible for facilitating internatio...
# 12  UNICEF's subject matter jurisdiction is focuse...
# 13  The WHO is responsible for directing and coord...
# 14  The OHCHR is responsible for protecting and pr...
# 15  The UNDRR Secretariat is responsible for preve...
# 16  The UN Global Compact  Office is responsible f...
# 17  The IAEA is responsible for ensuring the safe,...
# 18  The WMO Secretariat works to facilitate worldw...
# 19  The OECD is responsible for promoting economic...
# 20  The WBG provides loans, grants, and technical ...
# 21  The IMF is responsible for promoting internati...
# 22  IHO is responsible for advancing the science a...
# 23  ICES is committed to advancing and sharing sci...
# 24  The IPBES is an independent intergovernmental ...
# 25  The IPCC is responsible for assessing the scie...
# 26  The WTO is an international body that oversees...
# 27  The IOM is responsible for promoting humane an...
# 28  UNOPS is responsible for providing infrastruct...
# 29  UN-Women is responsible for advancing gender e...
# 30  The WIPO Secretariat is responsible for admini...
# 31  The UNFPA Secretariat is responsible for advan...
# 32  UN-Habitat is responsible for promoting social...
# 33  The World Food Programme (WFP) is responsible ...
# 34  The UNWTO is responsible for promoting respons...
# 35  The UNRISD Secretariat is a research and polic...
# 36  The BRS Secretariat is responsible for facilit...
# 37  The CBD Secretariat is responsible for facilit...
# 38  The CITES Secretariat is responsible for ensur...
# 39  The CMS secretariat is the coordinating body o...
# 40  The IFAD Secretariat is responsible for invest...
# 41  ITC is responsible for fostering sustainable e...
# 42  The UNCCD Secretariat is responsible for comba...
# 43  UNU is responsible for advancing global sustai...
# 44  The Ramsar Secretariat is responsible for coor...
# 45  The Minamata Convention is responsible for pro...
# 46  UNOOSA is responsible for promoting and facili...
# 47  UNODC is a global leader in the fight against ...
#
#                                Source of Jurisdiction  \
# 0   The IOC’s authority is derived from its statut...
# 1   The FAO’s jurisdiction is established through ...
# 2   The IMO's jurisdiction is established by the C...
# 3   DOALOS derives its mandate from the United Nat...
# 4   The UNFCCC Secretariat derives its mandate fro...
# 5   ISA derives its mandate from the United Nation...
# 6   UNEP derives its mandate from the United Natio...
# 7   UNDP derives its mandate from the United Natio...
# 8   UNCTAD derives its mandate from the United Nat...
# 9   UNIDO derives its mandate from its own Constit...
# 10  ILO derives its mandate from the Treaty of Ver...
# 11  ITU derives its mandate from the Constitution ...
# 12  UNICEF derives its mandate from the United Nat...
# 13  WHO derives its mandate from the Constitution ...
# 14  OHCHR derives its mandate from the Charter of ...
# 15  UNDRR derives its mandate from the United Nati...
# 16  The UN Global Compact Office derives its manda...
# 17  The IAEA derives its mandate from the Statute ...
# 18  WMO derives its mandate from the Convention of...
# 19  The OECD derives its mandate from the Conventi...
# 20  The WBG derives its mandate from the Articles ...
# 21  The IMF mainly derives its mandate from its Ar...
# 22  IHO derives its mandate from the Convention on...
# 23  ICES derives its mandate from the 1964 Convent...
# 24  IPBES derives its mandate from the 2010 Busan ...
# 25  The IPCC derives its mandate from the Decision...
# 26  The WTO derives its mandate from the Marrakesh...
# 27  IOM derives its mandate from the Constitution ...
# 28  UNOPS derives its mandate from the 2010 Genera...
# 29  UN-Women derives its mandate from the UN Gener...
# 30  WIPO derives its mandate from the Convention E...
# 31  UNFPA derives its mandate from the United Nati...
# 32  UN-Habitat derives its mandate from several UN...
# 33  The World Food Programme (WFP) derives its man...
# 34  UNWTO derives its mandate from the Statutes of...
# 35  UNRISD derives its mandate from the Statutes o...
# 36  The BRS Secretariat derives its mandate from t...
# 37  The CBD derives its mandate from the Conventio...
# 38  The CITES Secretariat derives its mandate from...
# 39  The CMS Secretariat derives its mandate from t...
# 40  IFAD derives its mandate from the Agreement Es...
# 41  ITC derives its mandate from the UN General As...
# 42  The UNCCD Secretariat derives its mandate from...
# 43  UNU derives its mandate from the Charter of th...
# 44  The Ramsar Secretariat derives its mandate fro...
# 45  The Minamata Convention derives its mandate fr...
# 46  UNOOSA derives its mandate from the UN General...
# 47  UNODC derives its jurisdiction from several le...
#
#                                    Defined Objectives  \
# 0   The objectives of the Intergovernmental Oceano...
# 1   As stated in Article 1 of the Constitution, FA...
# 2   According to Part I, Article 1 of the Internat...
# 3   According to the Secretary-General’s bulletin ...
# 4   The secretariat's duties under the Convention ...
# 5   According to Part XI, Section 4 of the United ...
# 6   According to the Governing Council decision 2/...
# 7   The objectives of UNDP as defined include: to ...
# 8   As per the  General Assembly resolution 1995 (...
# 9   According to Chapter I of the Constitution of ...
# 10  According to the Preamble and Chapter I of the...
# 11  ITU, per its Constitution (Chapter I, Article ...
# 12  According to the Preamble and Part I of the Co...
# 13  WHO's objective, as per its Constitution (Chap...
# 14  OHCHR, as mandated by General Assembly Resolut...
# 15  According to the Sendai Framework for Disaster...
# 16  According to the General Assembly resolution 7...
# 17  The International Atomic Energy Agency (IAEA),...
# 18  According to Part II, Article 2 of the Convent...
# 19  According to Article 1 of the Convention on th...
# 20  The objectives of the WBG are established in t...
# 21  According to Article I of the Articles of Agre...
# 22  According to Article II f the IHO Convention (...
# 23  According to the Convention for the ICES (http...
# 24  According to the Resolution on the IPBES durin...
# 25  As defined in Paragraph 2 of Resolution 4 (EC-...
# 26  According to Article III of the Marrakesh Agre...
# 27  According to Chapter I (Article 1) of the Cons...
# 28  According to the UNOPS strategic plan, 2022-20...
# 29  According to the Report of the Secretary-Gener...
# 30  According to the Convention Establishing the W...
# 31  The objectives of UNFPA as defined by the Prog...
# 32  According to the annex of UN General Assembly ...
# 33  According to Article II of the General Regulat...
# 34  According to Article 3 of the Statutes of the ...
# 35  According to the Statutes of UNRISD (https://d...
# 36  The BRS Secretariat's objectives encompass sev...
# 37  According to the Convention on Biological Dive...
# 38  According to Article XII of the Convention on ...
# 39  According to Article IX of the Convention on t...
# 40  According to Article 2 of the Agreement Establ...
# 41  According to paragraph 1 of resolution 2297 (X...
# 42  According to Article 23 of the UNCCD Conventio...
# 43  According to the Charter of the United Nations...
# 44  According to the Ramsar Convention (https://ww...
# 45  According to Article 1 of the Minamata Convent...
# 46  According to Part A, Section III of UNOOSA's w...
# 47  According to the Secretary-General's bulletin ...
#
#                                            Strategies  \
# 0   IOC implements its objectives through series o...
# 1    The FAO executes its objectives through a ser...
# 2   IMO implements its objectives and mandates thr...
# 3   . DOALOS) executes its objectives through a mu...
# 4   The UNFCCC Secretariat executes its objectives...
# 5   The International Seabed Authority (ISA) fulfi...
# 6   UNEP fulfills its objectives through diverse s...
# 7   The UNDP executes its objectives via several s...
# 8   The UNCTAD Secretariat implements its objectiv...
# 9   UNIDO executes its objectives via several stra...
# 10  ILO implements its objectives through strategi...
# 11  The ITU executes its objectives via several st...
# 12  UNICEF implements its objectives through sever...
# 13  The WHO executes its objectives via several st...
# 14  The OHCHR executes its objectives via several ...
# 15  The UNDRR executes its objectives via several ...
# 16  The UN Global Compact implements its objective...
# 17  The IAEA executes its objectives via several s...
# 18  The WMO Secretariat executes its objectives vi...
# 19  The OECD executes its objectives through multi...
# 20  The World Bank Group executes its objectives v...
# 21  The IMF implements its objectives through seve...
# 22  The IHO executes its objectives via several st...
# 23  ICES executes its objectives via several strat...
# 24  The IPBES Secretariat executes its defined obj...
# 25  The IPCC executes its objectives via several s...
# 26  The WTO has a comprehensive strategy in place ...
# 27  The IOM executes its objectives via several st...
# 28  The United Nations Office for Project Services...
# 29  UN-Women executes its objectives via several s...
# 30  The WIPO executes its objectives via several s...
# 31  The UNFPA executes its objectives via several ...
# 32  The UN-Habitat executes its objectives via sev...
# 33  The World Food Programme (WFP) executes its ob...
# 34  The United Nations World Tourism Organization ...
# 35  The UNRISD pursues its objectives and mandates...
# 36  The Secretariats of the Basel and Stockholm co...
# 37  The CBD Secretariat executes its objectives vi...
# 38  The CITES Secretariat executes its objectives ...
# 39  The CMS Secretariat executes its objectives vi...
# 40  IFAD executes its objectives via several strat...
# 41  ITC executes its objectives via several strate...
# 42  The UNCCD Secretariat executes its objectives ...
# 43  The United Nations University (UNU) implements...
# 44  The Ramsar Secretariat executes its defined ob...
# 45  The Minamata Convention Secretariat executes i...
# 46  The UNOOSA executes its objectives through cer...
# 47  UNODC executes its objectives and mandates by ...
#
#                      Inter-institutional Relationship  \
# 0   IOC collaborates with UN specialized agencies ...
# 1   As stated in its constitution, the FAO maintai...
# 2   The IMO collaborates with a diverse array of o...
# 3   DOALOS collaborates with key organizations to ...
# 4   The UNFCCC Secretariat maintains collaborative...
# 5   The ISA cooperates with various organizations ...
# 6   UNEP collaborates with a wide range of organiz...
# 7   UNDP collaborates with various partners to adv...
# 8   UNCTAD collaborates with various organizations...
# 9   UNIDO collaborates with various organizations ...
# 10  The ILO collaborates with various organization...
# 11  ITU collaborates with various organizations to...
# 12  UNICEF collaborates with a diverse range of or...
# 13  WHO collaborates with various organizations to...
# 14  OHCHR collaborates with various organizations ...
# 15  UNDRR collaborates with various organizations ...
# 16  The UN Global Compact cooperates with various ...
# 17  The IAEA collaborates with various organizatio...
# 18  The WMO collaborates with key organizations to...
# 19  OECD collaborates with various organizations t...
# 20  The WBG collaborates with a wide range of part...
# 21  The IMF collaborates with various institutions...
# 22  The IHO collaborates with various organisation...
# 23  ICES collaborates with various organizations, ...
# 24  IPBES collaborates with key organisations to s...
# 25  The Intergovernmental Panel on Climate Change ...
# 26  The WTO cooperates with various institutions t...
# 27  IOM cooperates with various partners to advanc...
# 28  UNOPS works with a variety of partners to supp...
# 29  UN-Women collaborates with key institutions to...
# 30  WIPO cooperates with various organisations to ...
# 31  UNFPA works with various partners to advance s...
# 32  UN-Habitat establishes and strengthens strateg...
# 33  WFP cooperates with various institutions to ac...
# 34  UNWTO cooperates with various institutions to ...
# 35  UNRISD engages with various institutions to ad...
# 36  The BRS Secretariat cooperates with key entiti...
# 37  The CBD Secretariat collaborates with key orga...
# 38  CITES cooperates with various institutions to ...
# 39  The CMS Secretariat works with various partner...
# 40  IFAD partners with various organizations to ac...
# 41  ITC works with various institutions to achieve...
# 42  The UNCCD Secretariat collaborates with variou...
# 43  The UNU collaborates with various institutions...
# 44  The Ramsar Secretariat collaborates with vario...
# 45  The Minamata Convention collaborates with key ...
# 46  UNOOSA cooperates with various organisations t...
# 47  UNODC collaborates with various institutions t...
#
#                       Practical Vertical Coordination  \
# 0   Vertical coordination within the IOC involves ...
# 1   The FAO’s vertical coordination involves colla...
# 2   Vertical coordination within IMO involves coll...
# 3   DOALOS engages in vertical coordination with v...
# 4   Vertical coordination within UNFCCC involves c...
# 5   Vertical coordination within ISA involves coop...
# 6   Vertical coordination within UNEP involves col...
# 7   Vertical coordination within UNDP involves wor...
# 8   Vertical coordination within UNCTAD involves c...
# 9   Vertical coordination within UNIDO involves co...
# 10  Vertical coordination within ILO involves coll...
# 11  Vertical coordination within ITU involves coll...
# 12  Vertical coordination within UNICEF involves c...
# 13  Vertical coordination within WHO involves coll...
# 14  Vertical coordination within OHCHR involves co...
# 15  Vertical coordination within UNDRR involves co...
# 16  Vertical coordination within the UN Global Com...
# 17  Vertical coordination within the IAEA involves...
# 18  Vertical coordination within the WMO involves ...
# 19   Vertical coordination connected to the OECD i...
# 20  Vertical coordination within the WBG involves ...
# 21  Vertical coordination within IMF involves coop...
# 22   Vertical coordination connected to the IHO in...
# 23  Vertical coordination within ICES involves coo...
# 24  Vertical coordination within IPBES involves co...
# 25  Vertical coordination within the IPCC involves...
# 26  Vertical coordination connected to the WTO inv...
# 27  Vertical coordination within IOM involves coop...
# 28  Vertical coordination within UNOPS involves wo...
# 29  Vertical coordination within UN-Women involves...
# 30  Vertical coordination within WIPO involves coo...
# 31  Vertical coordination within UNFPA involves co...
# 32  Vertical coordination within UN-Habitat involv...
# 33  Vertical coordination within WFP involves coop...
# 34  Vertical coordination within UNWTO involves co...
# 35  Vertical coordination within UNRISD involves c...
# 36  Vertical coordination within BRS Secretariat i...
# 37  Vertical coordination within the CBD Secretari...
# 38  Vertical coordination within the CITES Secreta...
# 39  Vertical coordination within the CMS Secretari...
# 40  Vertical coordination within IFAD involves col...
# 41  Vertical coordination within ITC involves coll...
# 42  Vertical coordination within UNCCD Secretariat...
# 43  Vertical coordination within UNU involves coll...
# 44  Vertical coordination within Ramsar Secretaria...
# 45  Vertical coordination within the Minamata Conv...
# 46  Vertical coordination within UNOOSA involves c...
# 47  Vertical coordination within UNODC involves co...
#
#                     Practical Horizontal Coordination
# 0   Horizontal coordination within the IOC encompa...
# 1   Horizontal coordination within the FAO involve...
# 2   Horizontal coordination within the IMO involve...
# 3   Horizontal coordination within DOALOS involves...
# 4   Horizontal coordination within the UNFCCC invo...
# 5   Horizontal coordination within the ISA involve...
# 6   Horizontal coordination within UNEP involves c...
# 7   Horizontal coordination within UNDP involves c...
# 8   Horizontal coordination within UNCTAD involves...
# 9   Horizontal coordination within UNIDO involves ...
# 10  Horizontal coordination within ILO involves co...
# 11  Horizontal coordination within ITU involves co...
# 12  Horizontal coordination within UNICEF involves...
# 13  Horizontal coordination within WHO involves co...
# 14  Horizontal coordination within OHCHR involves ...
# 15  Horizontal coordination within UNDRR involves ...
# 16  Horizontal coordination within the UN Global C...
# 17  Horizontal coordination within IAEA involves c...
# 18  Horizontal coordination within WMO involves co...
# 19  Horizontal coordination within the OECD involv...
# 20  Horizontal coordination within the World Bank ...
# 21  Horizontal coordination within the IMF involve...
# 22  Horizontal coordination within IHO involves co...
# 23  Horizontal coordination within ICES involves c...
# 24  Horizontal coordination within IPBES involves ...
# 25  Horizontal coordination within IPCC involves c...
# 26  Horizontal coordination within the WTO involve...
# 27  Horizontal coordination within IOM involves co...
# 28  Horizontal coordination within UNOPS involves ...
# 29  Horizontal coordination within UN-Women involv...
# 30  Horizontal coordination within WIPO involves c...
# 31  Horizontal coordination within UNFPA involves ...
# 32  Horizontal coordination within UN-Habitat invo...
# 33  Horizontal coordination within WFP involves wo...
# 34  Horizontal coordination within UNWTO involves ...
# 35  Horizontal coordination within UNRISD involves...
# 36  Horizontal coordination within BRS Secretariat...
# 37  Horizontal coordination within the Convention ...
# 38  Horizontal coordination within the CITES Secre...
# 39  Horizontal coordination within the CMS Secreta...
# 40  Horizontal coordination within IFAD involves c...
# 41  Horizontal coordination within ITC involves wo...
# 42  Horizontal coordination within the UNCCD Secre...
# 43  Horizontal coordination within the United Nati...
# 44  Horizontal coordination within the Ramsar Secr...
# 45  Horizontal coordination within the Minamata Co...
# 46  Horizontal coordination within UNOOSA involves...
# 47  Horizontal coordination within UNODC involves ...

# %% [markdown]
# ## Summarization

# %% [markdown]
# ### Step 1: Extracting URLs and References for Summarization
#
# To summarize the text under each dimension of the Intergovernmental Organizations (IGOs), I started by extracting all URLs and references to relevant documents mentioned within the text. This allowed me to remove the URLs from the content, ensuring that the summary would not lose essential context provided by the references.
#
# I utilized Python for this task and created a column in the dataset specifically for storing the extracted links and referenced documents. The extraction process focused on identifying and isolating web links (URLs) and legal or institutional references, such as treaties, conventions, and agreements, that were crucial to the understanding of the text but were not necessary for the summary itself.

# %%
import re

# Function to extract relevant references and return cleaned text (without references)
def extract_references_and_clean_text(text):
    # Regular expression to match URLs (http:// and https://)
    url_pattern = r'https?://[^\s]+'
    urls = re.findall(url_pattern, text)
    
    # List of treaties and agreements to match, case-insensitive
    treaties = re.findall(r'\b(UNCLOS|Paris Agreement|UN Convention on the Law of the Sea|Sustainable Development Goals|SDGs|Basel Convention|Minamata Convention|CBD|CITES|CMS|Outer Space Treaty|Outer Space Law|Kyoto Protocol|UNFCCC|Rio Declaration|Convention on Biological Diversity|World Trade Organization|WTO|International Labour Organization|ILO)\b', text, re.IGNORECASE)
    
    # Additional references such as legal documents or organizations
    documents = re.findall(r'\b(Resolution|Treaty|Convention|Agreement|Declaration|Charter|Protocol|Accord)\s+[A-Za-z0-9\-_]+\b', text)
    
    # Combine all references, ensuring there are no duplicates
    all_references = set(urls + treaties + documents)
    
    # Create the cleaned text by removing URLs and references from the text
    cleaned_text = re.sub(url_pattern, '', text)  # Remove URLs
    cleaned_text = re.sub(r'\b(UNCLOS|Paris Agreement|UN Convention on the Law of the Sea|Sustainable Development Goals|SDGs|Basel Convention|Minamata Convention|CBD|CITES|CMS|Outer Space Treaty|Outer Space Law|Kyoto Protocol|UNFCCC|Rio Declaration|Convention on Biological Diversity|World Trade Organization|WTO|International Labour Organization|ILO)\b', '', cleaned_text, flags=re.IGNORECASE)  # Remove specific treaty references
    cleaned_text = re.sub(r'\b(Resolution|Treaty|Convention|Agreement|Declaration|Charter|Protocol|Accord)\s+[A-Za-z0-9\-_]+\b', '', cleaned_text)  # Remove other legal document references
    
    # Return both the cleaned text and the references found
    return cleaned_text.strip(), ', '.join(all_references) if all_references else "None"

# %% [markdown]
# By extracting these references in advance, I was able to generate a cleaner, more focused summary of the text while preserving the critical information without including the URLs directly in the summary.
#
# #### Key Points:
# * **Objective:** The goal was to extract URLs and references to preserve the content's context while removing links from the summary.
# * **Tools Used:** Python, regular expressions, and pandas were used to extract and organize the URLs and document references.
# **Outcome:** A new column containing all relevant links and references was added to the dataset, making the subsequent summarization process more effective and focused.

# %%
# List of columns to process
columns_to_process = ['Spatial Jurisdiction','Subject Matter Jurisdiction', 'Source of Jurisdiction', 
                      'Defined Objectives', 'Strategies', 'Inter-institutional Relationship', 
                      'Practical Vertical Coordination', 'Practical Horizontal Coordination']

with pd.ExcelWriter(file_path, mode='a') as writer:
    # Loop through the columns and apply the extraction and cleaning function
    for column in columns_to_process:
        # Apply the function to each row of the column and create two new columns: <column> Cleaned and <column> References
        df[[f'{column} Cleaned', f'{column} References']] = df[column].apply(lambda x: pd.Series(extract_references_and_clean_text(x)))
        
        # Create a spatial_df (or similarly named DataFrame) for each column with cleaned data
        sub_df = df[['Institution', column, f'{column} Cleaned', f'{column} References']]
        
        # Save the spatial_df DataFrame to a sheet in the Excel file
        sub_df.to_excel(writer, sheet_name=f'{column}')
    
    print(f"Data has been saved to {file_path}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 16
#      13     sub_df = df[['Institution', column, f'{column} Cleaned', f'{column} References']]
#      15     # Save the spatial_df DataFrame to a sheet in the Excel file
# ---> 16     sub_df.to_excel(writer, sheet_name=f'{column}')
#      18 print(f"Data has been saved to {file_path}")
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/generic.py:2417, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2404 from pandas.io.formats.excel import ExcelFormatter
#    2406 formatter = ExcelFormatter(
#    2407     df,
#    2408     na_rep=na_rep,
#    (...)
#    2415     inf_rep=inf_rep,
#    2416 )
# -> 2417 formatter.write(
#    2418     excel_writer,
#    2419     sheet_name=sheet_name,
#    2420     startrow=startrow,
#    2421     startcol=startcol,
#    2422     freeze_panes=freeze_panes,
#    2423     engine=engine,
#    2424     storage_options=storage_options,
#    2425     engine_kwargs=engine_kwargs,
#    2426 )
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/io/formats/excel.py:952, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     949     need_save = True
#     951 try:
# --> 952     writer._write_cells(
#     953         formatted_cells,
#     954         sheet_name,
#     955         startrow=startrow,
#     956         startcol=startcol,
#     957         freeze_panes=freeze_panes,
#     958     )
#     959 finally:
#     960     # make sure to close opened file handles
#     961     if need_save:
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/io/excel/_openpyxl.py:463, in OpenpyxlWriter._write_cells(self, cells, sheet_name, startrow, startcol, freeze_panes)
#     461     wks = self.book.create_sheet(sheet_name, target_index)
#     462 elif self._if_sheet_exists == "error":
# --> 463     raise ValueError(
#     464         f"Sheet '{sheet_name}' already exists and "
#     465         f"if_sheet_exists is set to 'error'."
#     466     )
#     467 elif self._if_sheet_exists == "overlay":
#     468     wks = self.sheets[sheet_name]
#
# ValueError: Sheet 'Spatial Jurisdiction' already exists and if_sheet_exists is set to 'error'.

# %%
# # subsetting the cleaned data
# new_df = df[['Institution', 'Year', 'Scale', 'Spatial Jurisdiction Cleaned', 'Subject Matter Jurisdiction Cleaned', 'Source of Jurisdiction Cleaned', 'Defined Objectives Cleaned', 'Strategies Cleaned', 'Inter-institutional Relationship Cleaned', 'Practical Vertical Coordination Cleaned', 'Practical Horizontal Coordination Cleaned']]

# %%
# # Save Spatial df sheet
# with pd.ExcelWriter(file_path, mode='a') as writer:
#     new_df.to_excel(writer, sheet_name='Free Urls Raw Data', index=False)
