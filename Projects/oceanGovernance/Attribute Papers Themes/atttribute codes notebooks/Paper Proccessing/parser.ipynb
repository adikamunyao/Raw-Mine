# %%
# !pip install pdfquery
# !pip install pandas
# !pip install pdfminer.six

# %% [markdown]
# ### Papers Sections

# %%
import os
import pdfminer
from pdfminer.high_level import extract_text
import pandas as pd

# %%
# Function to extract text from a PDF using pdfminer
def extract_text_from_pdf(pdf_path):
    text = extract_text(pdf_path)
    return text

# Function to extract sections based on keywords from extracted text
def extract_section(text, section_name):
    # Search for the section and extract the relevant part of the text
    start = text.lower().find(section_name.lower())
    if start != -1:
        end = text.find('\n', start + len(section_name))  # Find the end of the section
        return text[start:end].strip()  # Extract the section text
    return ''

# Function to process all PDFs in the directory
def extract_from_pdfs(pdf_dir):
    # List all PDFs in the directory
    pdf_files = [f for f in os.listdir(pdf_dir) if f.endswith('.pdf')]
    
    data = []
    
    for pdf_file in pdf_files:
        pdf_path = os.path.join(pdf_dir, pdf_file)
        
        # Extract text from the PDF
        text = extract_text_from_pdf(pdf_path)
        
        # Extract sections (abstract, introduction, conclusion)
        abstract = extract_section(text, "Abstract")
        introduction = extract_section(text, "Introduction")
        conclusion = extract_section(text, "Conclusion")
        
        # Add the extracted data to the list
        data.append({
            "PDF": pdf_file,
            "Abstract": abstract,
            "Introduction": introduction,
            "Conclusion": conclusion
        })
    
    return data

# Function to save extracted data to a CSV file
def save_to_csv(data, output_file):
    df = pd.DataFrame(data)
    df.to_csv(output_file, index=False)
    print(f"Data saved to {output_file}")

# Define the path to your PDFs
pdf_dir = '../Data/Attribute_Papers/'

# Extract data from the PDFs
extracted_data = extract_from_pdfs(pdf_dir)

# Save the extracted data to a CSV
save_to_csv(extracted_data, 'extracted_text.csv')
# Out:
# The PDF <_io.BufferedReader name='../Data/Attribute_Papers/The complexification of the United Nations system.pdf'> contains a metadata field indicating that it should not allow text extraction. Ignoring this field and proceeding. Use the check_extractable if you want to raise an error in this case
# Data saved to extracted_text.csv

# %% [markdown]
# ### Text Extraction

# %%
import fitz  # PyMuPDF
import re

# %%
# Step 1: Extract text from PDF using PyMuPDF
def extract_text_from_pdf(pdf_path):
    # Open the PDF file
    document = fitz.open(pdf_path)
    
    # Extract text from each page
    full_text = ""
    for page_num in range(len(document)):
        page = document.load_page(page_num)
        full_text += page.get_text("text")  # Extract raw text from the page
    
    return full_text

# Step 2: Segment the extracted text into sections based on heuristics
def segment_text_into_sections(text):
    # Heuristic to detect headings - large font sizes or bold text
    section_pattern = re.compile(r'([A-Z][A-Z\s]+|[A-Za-z0-9\s]+[A-Za-z])(\n|\s+)', re.MULTILINE)
    
    # Find headings (titles or subheadings)
    headings = section_pattern.findall(text)
    
    # Split the text into sections based on headings
    sections = []
    start_index = 0
    for heading, _ in headings:
        # Find the position of the heading
        section_start = text.find(heading, start_index)
        
        # The end of the section is where the next heading begins or end of text
        next_heading = text.find(headings[headings.index((heading, _)) + 1][0], section_start) if (headings.index((heading, _)) + 1) < len(headings) else len(text)
        
        section_content = text[section_start:next_heading].strip()
        
        # Store the section with its heading
        sections.append({"heading": heading.strip(), "content": section_content})
        start_index = next_heading
    
    return sections

# Step 3: Example function to process a single PDF
def process_pdf(pdf_path):
    # Extract text from PDF
    extracted_text = extract_text_from_pdf(pdf_path)
    
    # Segment text into sections
    sections = segment_text_into_sections(extracted_text)
    
    # Display the extracted sections (for inspection)
    for section in sections:
        print(f"Section: {section['heading']}")
        print(f"Content: {section['content'][:1000]}...")  # Print first 300 chars of content for preview
        print("-" * 80)  # Separator for clarity

# %%
# Example usage with a single PDF file
pdf_path = '../Data/Attribute_Papers/Why states act through formal international organizations.pdf'
process_pdf(pdf_path)
# Out:
# Section: Why States Act through Formal International Organizations
# Content: Why States Act through Formal International Organizations
# Author(s):...
# --------------------------------------------------------------------------------
# Section: Kenneth
# Content: Kenneth W....
# --------------------------------------------------------------------------------
# Section: Abbott and  Duncan Snidal
# Content: Abbott and  Duncan Snidal
# Source:...
# --------------------------------------------------------------------------------
# Section: The Journal of Conflict
# Content: The Journal of Conflict Resolution, Vol. 42, No. 1 (Feb., 1998), pp. 3-...
# --------------------------------------------------------------------------------
# Section: 32
# Published
# Content: 32
# Published by:...
# --------------------------------------------------------------------------------
# Section: Sage
# Content: Sage Publications, Inc....
# --------------------------------------------------------------------------------
# Section: Stable
# Content: Stable URL: https://www.jstor.org/stable/174551
# Accessed: 26-11-2024 20:...
# --------------------------------------------------------------------------------
# Section: 22 UTC
#
# JSTOR is a
# Content: 22 UTC
#
# JSTOR is a not-for-...
# --------------------------------------------------------------------------------
# Section: profit service that helps
# Content: profit service that helps scholars, researchers,...
# --------------------------------------------------------------------------------
# Section: and students
# Content: and students discover, use,...
# --------------------------------------------------------------------------------
# Section: and build upon a wide
# range of content in a trusted digital
# Content: and build upon a wide
# range of content in a trusted digital archive....
# --------------------------------------------------------------------------------
# Section: We use information technology and tools to increase productivity and
# facilitate new forms of
# Content: We use information technology and tools to increase productivity and
# facilitate new forms of scholarship....
# --------------------------------------------------------------------------------
# Section: For more information about
# Content: For more information about JSTOR,...
# --------------------------------------------------------------------------------
# Section: please contact
# Content: please contact support@jstor.org....
# --------------------------------------------------------------------------------
# Section: Your use of the JSTOR archive indicates your acceptance of the Terms
# Content: Your use of the JSTOR archive indicates your acceptance of the Terms &...
# --------------------------------------------------------------------------------
# Section: Conditions of
# Content: Conditions of Use,...
# --------------------------------------------------------------------------------
# Section: available at
# Content: available at
# https://about.jstor.org/...
# --------------------------------------------------------------------------------
# Section: terms
# Sage
# Content: terms
# Sage Publications, Inc....
# --------------------------------------------------------------------------------
# Section: is collaborating with JSTOR to
# Content: is collaborating with JSTOR to digitize,...
# --------------------------------------------------------------------------------
# Section: preserve and extend access to
# The Journal of Conflict Resolution
# This content downloaded from
# Content: preserve and extend access to
# The Journal of Conflict Resolution
# This content downloaded from 102.64.114....
# --------------------------------------------------------------------------------
# Section: 122 on
# Content: 122 on Tue,...
# --------------------------------------------------------------------------------
# Section: 26 Nov
# Content: 26 Nov 2024 20:22:...
# --------------------------------------------------------------------------------
# Section: 45 UTC
# All use subject to
# Content: 45 UTC
# All use subject to https://about.jstor.org/...
# --------------------------------------------------------------------------------
# Section: terms
# Why States Act through Formal
# International Organizations
# KENNETH
# Content: terms
# Why States Act through Formal
# International Organizations
# KENNETH W....
# --------------------------------------------------------------------------------
# Section: ABBOTT
# Graduate and International Studies
# Northwestern University School of Law
# DUNCAN SNIDAL
# Department of Political Science
# University of Chicago
# States use formal international organizations
# Content: ABBOTT
# Graduate and International Studies
# Northwestern University School of Law
# DUNCAN SNIDAL
# Department of Political Science
# University of Chicago
# States use formal international organizations (1Os)...
# --------------------------------------------------------------------------------
# Section: to manage both their everyday interactions and more
# dramatic
# Content: to manage both their everyday interactions and more
# dramatic episodes,...
# --------------------------------------------------------------------------------
# Section: including international
# Content: including international conflicts. Yet,...
# --------------------------------------------------------------------------------
# Section: contemporary international theory does not explain
# the existence or form of
# Content: contemporary international theory does not explain
# the existence or form of 1Os....
# --------------------------------------------------------------------------------
# Section: This article addresses the question of why states use formal organizations by
# investigating the functions 1Os perform and the properties that enable them to perform those
# Content: This article addresses the question of why states use formal organizations by
# investigating the functions 1Os perform and the properties that enable them to perform those functions....
# --------------------------------------------------------------------------------
# Section: Starting with a
# Content: Starting with a rational-...
# --------------------------------------------------------------------------------
# Section: institutionalist perspective that sees 1Os as enabling states to achieve their
# Content: institutionalist perspective that sees 1Os as enabling states to achieve their ends,...
# --------------------------------------------------------------------------------
# Section: the
# authors examine power and distributive questions and the role of 1Os in creating norms and
# Content: the
# authors examine power and distributive questions and the role of 1Os in creating norms and understanding....
# --------------------------------------------------------------------------------
# Section: Centralization and independence are identified as the key properties of formal
# Content: Centralization and independence are identified as the key properties of formal organizations,...
# --------------------------------------------------------------------------------
# Section: and their
# importance is illustrated with a wide array of
# Content: and their
# importance is illustrated with a wide array of examples....
# --------------------------------------------------------------------------------
# Section: 1Os as community representatives further allow
# states to create and implement community values and enforce international
# Content: 1Os as community representatives further allow
# states to create and implement community values and enforce international commitments.
# *...
# --------------------------------------------------------------------------------
# Section: When the United States decided to reverse the Iraqi invasion of
# Content: When the United States decided to reverse the Iraqi invasion of Kuwait,...
# --------------------------------------------------------------------------------
# Section: it did not act
# unilaterally
# Content: it did not act
# unilaterally (...
# --------------------------------------------------------------------------------
# Section: although it often
# Content: although it often does)....
# --------------------------------------------------------------------------------
# Section: It turned to the United Nations
# Content: It turned to the United Nations (UN)...
# --------------------------------------------------------------------------------
# Section: Security
# Content: Security
# Council....
# --------------------------------------------------------------------------------
# Section: e When the Security Council sought to learn the extent of
# Content: e When the Security Council sought to learn the extent of chemical, biological,...
# --------------------------------------------------------------------------------
# Section: and nuclear
# arms in
# Content: and nuclear
# arms in Iraq,...
# --------------------------------------------------------------------------------
# Section: it did not rely on
# Content: it did not rely on U.S. forces....
# --------------------------------------------------------------------------------
# Section: It dispatched inspectors from the International
# Atomic Energy Agency
# Content: It dispatched inspectors from the International
# Atomic Energy Agency (IAEA).
# *...
# --------------------------------------------------------------------------------
# Section: When the international community sought to maintain the suspension of combat in
# Content: When the international community sought to maintain the suspension of combat in
# Bosnia,...
# --------------------------------------------------------------------------------
# Section: it did not rely only on national
# Content: it did not rely only on national efforts....
# --------------------------------------------------------------------------------
# Section: It sent in peacekeeping units under the
# aegis of the UN and North Atlantic Treaty Organization
# Content: It sent in peacekeeping units under the
# aegis of the UN and North Atlantic Treaty Organization (NATO).
# *...
# --------------------------------------------------------------------------------
# Section: When states liberalized trade in services and strengthened intellectual property protection
# in the Uruguay
# Content: When states liberalized trade in services and strengthened intellectual property protection
# in the Uruguay Round,...
# --------------------------------------------------------------------------------
# Section: they were not content to draft
# Content: they were not content to draft rules....
# --------------------------------------------------------------------------------
# Section: They created the World Trade
# Organization
# Content: They created the World Trade
# Organization (WTO)...
# --------------------------------------------------------------------------------
# Section: and a highly institutionalized dispute settlement
# Content: and a highly institutionalized dispute settlement mechanism....
# --------------------------------------------------------------------------------
# Section: Formal international organizations
# Content: Formal international organizations (IOs)...
# --------------------------------------------------------------------------------
# Section: are prominent
# Content: are prominent (...
# --------------------------------------------------------------------------------
# Section: if not always
# Content: if not always successful)...
# --------------------------------------------------------------------------------
# Section: participants in many critical episodes in international
# Content: participants in many critical episodes in international politics....
# --------------------------------------------------------------------------------
# Section: Examples in addition
# Content: Examples in addition
# AUTHORS' NOTE:...
# --------------------------------------------------------------------------------
# Section: We are grateful for valuable comments from Lea
# Content: We are grateful for valuable comments from Lea Brilmayer,...
# --------------------------------------------------------------------------------
# Section: Judith
# Content: Judith Goldstein,...
# --------------------------------------------------------------------------------
# Section: Charles
# Content: Charles
# Lipson,...
# --------------------------------------------------------------------------------
# Section: Andrew
# Content: Andrew Moravcsik,...
# --------------------------------------------------------------------------------
# Section: James
# Content: James Morrow, Anne-...
# --------------------------------------------------------------------------------
# Section: Marie
# Content: Marie Slaughter,...
# --------------------------------------------------------------------------------
# Section: and seminar participants at the University
# of California at
# Content: and seminar participants at the University
# of California at Berkeley,...
# --------------------------------------------------------------------------------
# Section: Harvard University Law
# Content: Harvard University Law School,...
# --------------------------------------------------------------------------------
# Section: New York University Law
# Content: New York University Law School,...
# --------------------------------------------------------------------------------
# Section: Princeton
# Content: Princeton
# University,...
# --------------------------------------------------------------------------------
# Section: and the Program on International
# Content: and the Program on International Politics,...
# --------------------------------------------------------------------------------
# Section: Economics and Security
# Content: Economics and Security (PIPES)...
# --------------------------------------------------------------------------------
# Section: at the University of
# Content: at the University of
# Chicago....
# --------------------------------------------------------------------------------
# Section: For financial
# Content: For financial support,...
# --------------------------------------------------------------------------------
# Section: Abbott thanks the Russell Baker
# Content: Abbott thanks the Russell Baker Fund,...
# --------------------------------------------------------------------------------
# Section: the Charles
# Content: the Charles C....
# --------------------------------------------------------------------------------
# Section: Linthicum
# Content: Linthicum Fund,...
# --------------------------------------------------------------------------------
# Section: and the
# Northwestern Summer Research Grant
# Content: and the
# Northwestern Summer Research Grant program....
# --------------------------------------------------------------------------------
# Section: JOURNAL OF CONFLICT
# Content: JOURNAL OF CONFLICT RESOLUTION, Vol. 42 No. 1,...
# --------------------------------------------------------------------------------
# Section: February
# Content: February 1998 3-32
# ?...
# --------------------------------------------------------------------------------
# Section: 1998 Sage
# Content: 1998 Sage Publications, Inc....
# --------------------------------------------------------------------------------
# Section: 3
# This content downloaded from
# Content: 3
# This content downloaded from 102.64.114....
# --------------------------------------------------------------------------------
# Section: 122 on
# Content: 122 on Tue,...
# --------------------------------------------------------------------------------
# Section: 26 Nov
# Content: 26 Nov 2024 20:22:...
# --------------------------------------------------------------------------------
# Section: 45 UTC
# All use subject to
# Content: 45 UTC
# All use subject to https://about.jstor.org/terms
# 4 JOURNAL OF CONFLICTRESOLUTION
# to those above include the following: Security Council sanctions on Libya, IAEA
# inspectors in North Korea, UN peacekeepers in the Middle East, and so forth. The UN
# secretary-general's 1992 Agenda for Peace sets out an even broader range of current
# and proposed UN functions in situations of international conflict: fact finding, early
# warning, and preventive deployment; mediation, adjudication, and other forms of
# dispute resolution; peacekeeping; sanctions and military force; impartial humanitarian
# assistance; and postconflict rebuilding. But IO influence is not confined to dramatic
# interventions like these. On an ongoing basis, formal organizations help manage many
# significant areas of interstate relations, from global health policy (the WHO) to
# European security (OSCE and NATO) to international monetary policy (IMF). What
# is more, participation in such organizations appears to reduce the likelihood ...
# --------------------------------------------------------------------------------
# Section: terms
# 4 JOURNAL OF CONFLICTRESOLUTION
# to those above include the
# Content: ...
# --------------------------------------------------------------------------------
# Section: Security Council sanctions on
# Content: ...
# --------------------------------------------------------------------------------
# Section: IAEA
# inspectors in North
# Content: ...
# --------------------------------------------------------------------------------
# Section: UN peacekeepers in the Middle
# Content: ...
# --------------------------------------------------------------------------------
# Section: and so
# Content: ...
# --------------------------------------------------------------------------------
# Section: The UN
# Content: ...
# --------------------------------------------------------------------------------
# Section: s 1992 Agenda for Peace sets out an even broader range of current
# and proposed UN functions in situations of international
# Content: ...
# --------------------------------------------------------------------------------
# Section: fact
# Content: ...
# --------------------------------------------------------------------------------
# Section: early
# Content: ...
# --------------------------------------------------------------------------------
# Section: and preventive
# Content: ...
# --------------------------------------------------------------------------------
# Section: and other forms of
# dispute
# Content: ...
# --------------------------------------------------------------------------------
# Section: sanctions and military
# Content: ...
# --------------------------------------------------------------------------------
# Section: impartial humanitarian
# Content: ...
# --------------------------------------------------------------------------------
# Section: and postconflict
# Content: ...
# --------------------------------------------------------------------------------
# Section: But IO influence is not confined to dramatic
# interventions like
# Content: ...
# --------------------------------------------------------------------------------
# Section: On an ongoing
# Content: ...
# --------------------------------------------------------------------------------
# Section: formal organizations help manage many
# significant areas of interstate
# Content: ...
# --------------------------------------------------------------------------------
# Section: from global health policy
# Content: ...
# --------------------------------------------------------------------------------
# Section: the
# Content: ...
# --------------------------------------------------------------------------------
# Section: to
# European security
# Content: ...
# --------------------------------------------------------------------------------
# Section: OSCE
# Content: ...
# --------------------------------------------------------------------------------
# Section: and
# Content: ...
# --------------------------------------------------------------------------------
# Section: to international monetary policy
# Content: ...
# --------------------------------------------------------------------------------
# Section: What
# is
# Content: ...
# --------------------------------------------------------------------------------
# Section: participation in such organizations appears to reduce the likelihood of violent
# conflict among member states
# Content: ...
# --------------------------------------------------------------------------------
# Section: and Davis in
# Content: ...
# --------------------------------------------------------------------------------
# Section: IOs range from simple entities like the APEC
# Content: ...
# --------------------------------------------------------------------------------
# Section: with an initial budget of
# Content: ...
# --------------------------------------------------------------------------------
# Section: to formidable organizations like the European Union
# Content: ...
# --------------------------------------------------------------------------------
# Section: 1 and the World
# Content: ...
# --------------------------------------------------------------------------------
# Section: which has thousands of employees and multiple affiliates and lends billions of
# dollars each
# Content: ...
# --------------------------------------------------------------------------------
# Section: Specialized agencies like the
# Content: ...
# --------------------------------------------------------------------------------
# Section: and FAO play key roles
# in technical issue
# Content: ...
# --------------------------------------------------------------------------------
# Section: New organizations like
# Content: ...
# --------------------------------------------------------------------------------
# Section: the
# Content: ...
# --------------------------------------------------------------------------------
# Section: and the
# Content: ...
# --------------------------------------------------------------------------------
# Section: tional Tribunal for the former Yugoslavia are regularly
# Content: ...
# --------------------------------------------------------------------------------
# Section: Older IOs like NATO
# and the Security Council are rethought and sometimes restructured to meet new
# Content: ...
# --------------------------------------------------------------------------------
# Section: 2 As the examples
# Content: ...
# --------------------------------------------------------------------------------
# Section: even the most powerful states
# often act through
# Content: ...
# --------------------------------------------------------------------------------
# Section: In
# Content: ...
# --------------------------------------------------------------------------------
# Section: it is impossible to imagine contemporary international
# Content: ...
# --------------------------------------------------------------------------------
# Section: without formal organizations
# Content: ...
# --------------------------------------------------------------------------------
# Section: Schermers and Blokker
# Content: ...
# --------------------------------------------------------------------------------
# Section: Why do states so frequently use IOs as vehicles of
# Content: ...
# --------------------------------------------------------------------------------
# Section: What attributes
# account for their
# Content: ...
# --------------------------------------------------------------------------------
# Section: and how do these characteristics set formal organizations apart
# from alternative
# Content: ...
# --------------------------------------------------------------------------------
# Section: such as decentralized
# Content: ...
# --------------------------------------------------------------------------------
# Section: informal
# Content: ...
# --------------------------------------------------------------------------------
# Section: and treaty
# Content: ...
# --------------------------------------------------------------------------------
# Section: contemporary international scholarship has no
# clear theoretical answers to such questions and thus offers limited practical advice to
# policy
# Content: ...
# --------------------------------------------------------------------------------
# Section: We answer these questions by identifying the functional attributes of IOs across a
# range of issue
# Content: ...
# --------------------------------------------------------------------------------
# Section: Although we are concerned with the concrete structure and
# operations of particular
# Content: ...
# --------------------------------------------------------------------------------
# Section: we also see IOs as complex phenomena that
# implicate several lines of international relations
# Content: ...
# --------------------------------------------------------------------------------
# Section: From this vantage
# Content: ...
# --------------------------------------------------------------------------------
# Section: we identify two functional characteristics that lead
# Content: ...
# --------------------------------------------------------------------------------
# Section: in appropriate
# Content: ...
# --------------------------------------------------------------------------------
# Section: to prefer IOs to alternate forms of
# Content: ...
# --------------------------------------------------------------------------------
# Section: These are centralization
# and
# Content: ...
# --------------------------------------------------------------------------------
# Section: IOs allow for the centralization of collective activities through a concrete and stable
# organizational structure and a supportive administrative
# Content: ...
# --------------------------------------------------------------------------------
# Section: These increase the
# Content: ...
# --------------------------------------------------------------------------------
# Section: Although we discuss certain of its
# Content: ...
# --------------------------------------------------------------------------------
# Section: we deliberately
# Content: ...
# --------------------------------------------------------------------------------
# Section: emphasize the EU because some
# would regard it as an exceptional case of
# Content: ...
# --------------------------------------------------------------------------------
# Section: A discussion of 1Os is an exercise in
# Content: ...
# --------------------------------------------------------------------------------
# Section: The ones not identified in the
# Content: ...
# --------------------------------------------------------------------------------
# Section: in
# Content: ...
# --------------------------------------------------------------------------------
# Section: are the
# World Health Organization
# Content: ...
# --------------------------------------------------------------------------------
# Section: Organization for Security and Cooperation in Europe
# Content: ...
# --------------------------------------------------------------------------------
# Section: International Monetary Fund
# Content: ...
# --------------------------------------------------------------------------------
# Section: Pacific Economic Cooperation forum
# Content: ...
# --------------------------------------------------------------------------------
# Section: International
# Labor Organization
# Content: ...
# --------------------------------------------------------------------------------
# Section: International Civil Aviation Organization
# Content: ...
# --------------------------------------------------------------------------------
# Section: Food and Agriculture
# Content: ...
# --------------------------------------------------------------------------------
# Section: nization
# Content: ...
# --------------------------------------------------------------------------------
# Section: United Nations Environment Program
# Content: ...
# --------------------------------------------------------------------------------
# Section: and European Bank for Reconstruction and
# Development
# Content: ...
# --------------------------------------------------------------------------------
# Section: This content downloaded from
# Content: ...
# --------------------------------------------------------------------------------
# Section: 122 on
# Content: ...
# --------------------------------------------------------------------------------
# Section: 26 Nov
# Content: ...
# --------------------------------------------------------------------------------
# Section: 45 UTC
# All use subject to
# Content: ...
# --------------------------------------------------------------------------------
# Section: terms
# Content: ...
# --------------------------------------------------------------------------------
# Section: FORMAL INTERNATIONAL ORGANIZATIONS
# Content: ...
# --------------------------------------------------------------------------------
# Section: 5
# efficiency of collective activities and enhance the
# Content: ...
# --------------------------------------------------------------------------------
# Section: s ability to affect the
# Content: ...
# --------------------------------------------------------------------------------
# Section: and interests of
# Content: ...
# --------------------------------------------------------------------------------
# Section: Independence means the ability
# to act with a degree of autonomy within defined
# Content: ...
# --------------------------------------------------------------------------------
# Section: It often entails the capacity
# to operate as a neutral in managing interstate disputes and
# Content: ...
# --------------------------------------------------------------------------------
# Section: IO independence
# is highly
# Content: ...
# --------------------------------------------------------------------------------
# Section: member
# Content: ...
# --------------------------------------------------------------------------------
# Section: especially the
# Content: ...
# --------------------------------------------------------------------------------
# Section: can limit the autonomy
# of
# Content: ...
# --------------------------------------------------------------------------------
# Section: interfere with their
# Content: ...
# --------------------------------------------------------------------------------
# Section: ignore their
# Content: ...
# --------------------------------------------------------------------------------
# Section: or restructure and dissolve
# Content: ...
# --------------------------------------------------------------------------------
# Section: But as in many private
# Content: ...
# --------------------------------------------------------------------------------
# Section: participation by even a partially
# Content: ...
# --------------------------------------------------------------------------------
# Section: neutral actor can increase efficiency and affect the legitimacy of individual and
# collective
# Content: ...
# --------------------------------------------------------------------------------
# Section: This provides even powerful states with incentives to grant IOs
# substantial
# Content: ...
# --------------------------------------------------------------------------------
# Section: The broad categories of centralization and independence encompass numerous
# specific
# Content: ...
# --------------------------------------------------------------------------------
# Section: Most IOs perform more than
# Content: ...
# --------------------------------------------------------------------------------
# Section: though each has its own unique
# Content: ...
# --------------------------------------------------------------------------------
# Section: We do not enumerate every such function or provide a comprehensive
# Content: ...
# --------------------------------------------------------------------------------
# Section: we highlight several of the most
# Content: ...
# --------------------------------------------------------------------------------
# Section: We focus especially on
# the active functions of
# Content: ...
# --------------------------------------------------------------------------------
# Section: facilitating the negotiation and implementation of
# Content: ...
# --------------------------------------------------------------------------------
# Section: resolving
# Content: ...
# --------------------------------------------------------------------------------
# Section: managing
# Content: ...
# --------------------------------------------------------------------------------
# Section: carrying out operational activities like
# technical
# Content: ...
# --------------------------------------------------------------------------------
# Section: elaborating
# Content: ...
# --------------------------------------------------------------------------------
# Section: shaping international
# Content: ...
# --------------------------------------------------------------------------------
# Section: and the
# Content: ...
# --------------------------------------------------------------------------------
# Section: that IR theory has only sparingly
# Content: ...
# --------------------------------------------------------------------------------
# Section: Rational states will use or create a
# formal IO when the value of these functions outweighs the
# Content: ...
# --------------------------------------------------------------------------------
# Section: notably the resulting
# limits on unilateral
# Content: ...
# --------------------------------------------------------------------------------
# Section: Distinguishing formal IOs from alternative forms of organization is important from
# several
# Content: ...
# --------------------------------------------------------------------------------
# Section: For IR
# Content: ...
# --------------------------------------------------------------------------------
# Section: who largely abandoned the study of formal IOs
# in the move from the
# Content: ...
# --------------------------------------------------------------------------------
# Section: descriptive tradition to more theoretical
# Content: ...
# --------------------------------------------------------------------------------
# Section: developing such distinctions should
# Content: ...
# --------------------------------------------------------------------------------
# Section: open up a large and important research
# Content: ...
# --------------------------------------------------------------------------------
# Section: with institutional form and structure as central dependent variables
# Content: ...
# --------------------------------------------------------------------------------
# Section: Young
# Content: ...
# --------------------------------------------------------------------------------
# Section: see also Koremenos et
# Content: ...
# --------------------------------------------------------------------------------
# Section: This will complement emerging work on international
# Content: ...
# --------------------------------------------------------------------------------
# Section: a closely related form of institutionalization
# Content: ...
# --------------------------------------------------------------------------------
# Section: Burley and Mattli
# Content: ...
# --------------------------------------------------------------------------------
# Section: Abbott and Snidal
# Content: ...
# --------------------------------------------------------------------------------
# Section: and Slaughter
# Content: ...
# --------------------------------------------------------------------------------
# Section: Such research
# will also benefit practitioners of conflict management and regime design
# Content: ...
# --------------------------------------------------------------------------------
# Section: Mitchell
# Content: ...
# --------------------------------------------------------------------------------
# Section: The policy implications of our analysis are significant as
# Content: ...
# --------------------------------------------------------------------------------
# Section: Many
# Content: ...
# --------------------------------------------------------------------------------
# Section: notably the United
# Content: ...
# --------------------------------------------------------------------------------
# Section: now resist the creation of IOs and hesitate to support those
# already in
# Content: ...
# --------------------------------------------------------------------------------
# Section: citing the shortcomings of international
# Content: ...
# --------------------------------------------------------------------------------
# Section: the costs of
# formal
# Content: ...
# --------------------------------------------------------------------------------
# Section: and the irritations of IO
# Content: ...
# --------------------------------------------------------------------------------
# Section: This is an ideal time for
# students of international governance to focus on the other side of the
# Content: ...
# --------------------------------------------------------------------------------
# Section: The next section spells out our theoretical
# Content: ...
# --------------------------------------------------------------------------------
# Section: drawing lessons from the ways
# in which different schools of theory have dealt with
# Content: ...
# --------------------------------------------------------------------------------
# Section: or have failed to deal
# Content: ...
# --------------------------------------------------------------------------------
# Section: the
# questions posed
# Content: ...
# --------------------------------------------------------------------------------
# Section: It is followed by an analysis of the organizational attributes of
# centralization and independence and the functions they make
# Content: ...
# --------------------------------------------------------------------------------
# Section: especially in
# contexts of cooperation and nonviolent
# Content: ...
# --------------------------------------------------------------------------------
# Section: The final section explores two
# composite functions that challenge conventional views of IO capabilities and
# Content: ...
# --------------------------------------------------------------------------------
# Section: strate the complementarity of prevailing
# Content: ...
# --------------------------------------------------------------------------------
# Section: and carrying
# out community norms and aspirations and enforcing rules and
# Content: ...
# --------------------------------------------------------------------------------
# Section: We
# conclude with the example of the Security Council in the Gulf
# Content: ...
# --------------------------------------------------------------------------------
# Section: which draws
# together these themes in the context of violent
# Content: ...
# --------------------------------------------------------------------------------
# Section: This content downloaded from
# Content: ...
# --------------------------------------------------------------------------------
# Section: 122 on
# Content: ...
# --------------------------------------------------------------------------------
# Section: 26 Nov
# Content: ...
# --------------------------------------------------------------------------------
# Section: 45 UTC
# All use subject to
# Content: ...
# --------------------------------------------------------------------------------
# Section: terms
# 6 JOURNAL OF CONFLICTRESOLUTION
# PUTTING 1Os INTO THEORY
# AND THEORY INTO lOs
# Our primary approach is rationalist and
# Content: ...
# --------------------------------------------------------------------------------
# Section: We
# Content: ...
# --------------------------------------------------------------------------------
# Section: for
# Content: ...
# --------------------------------------------------------------------------------
# Section: that states are the principal actors in world politics and that they use IOs to create social
# orderings appropriate to their pursuit of shared
# Content: ...
# --------------------------------------------------------------------------------
# Section: producing collective
# Content: ...
# --------------------------------------------------------------------------------
# Section: collaborating in
# Content: ...
# --------------------------------------------------------------------------------
# Section: s dilemma
# Content: ...
# --------------------------------------------------------------------------------
# Section: solving coordination
# Content: ...
# --------------------------------------------------------------------------------
# Section: and the
# Content: ...
# --------------------------------------------------------------------------------
# Section: We start with the pursuit of efficiency and employ the logic of transaction costs
# economics and rational choice
# Content: ...
# --------------------------------------------------------------------------------
# Section: Snidal
# Content: ...
# --------------------------------------------------------------------------------
# Section: using analogies with business firms and
# medieval trading
# Content: ...
# --------------------------------------------------------------------------------
# Section: Decentralized cooperation theory
# Content: ...
# --------------------------------------------------------------------------------
# Section: gime theory provide a strong deductive basis for this
# Content: ...
# --------------------------------------------------------------------------------
# Section: Regime theory
# Content: ...
# --------------------------------------------------------------------------------
# Section: Krasner
# Content: ...
# --------------------------------------------------------------------------------
# Section: Keohane
# Content: ...
# --------------------------------------------------------------------------------
# Section: represents a major advance in
# understanding international
# Content: ...
# --------------------------------------------------------------------------------
# Section: It is
# Content: ...
# --------------------------------------------------------------------------------
# Section: consciously theoretical and focuses
# directly on the institutional organization of international
# Content: ...
# --------------------------------------------------------------------------------
# Section: But it has several
# Content: ...
# --------------------------------------------------------------------------------
# Section: Most
# Content: ...
# --------------------------------------------------------------------------------
# Section: regime scholars embrace an earlier turn in
# Content: ...
# --------------------------------------------------------------------------------
# Section: which
# unnecessarily coupled a move to theory with a move away from consideration of IOs
# Content: ...
# --------------------------------------------------------------------------------
# Section: This resulted in
# Content: ...
# --------------------------------------------------------------------------------
# Section: the steady disengagement of international organization
# scholars from the study of
# Content: ...
# --------------------------------------------------------------------------------
# Section: to the point that today one must question
# whether such a field even exists any longer except in name
# Content: ...
# --------------------------------------------------------------------------------
# Section: Rochester
# Content: ...
# --------------------------------------------------------------------------------
# Section: regime theory deals with institutions at such a general level that it
# has little to say about the particular institutional arrangements that organize
# Content: ...
# --------------------------------------------------------------------------------
# Section: tional
# Content: ...
# --------------------------------------------------------------------------------
# Section: Our focus on the concrete operations of formal 1Os not only brings them
# into regime theory but also provides a broader opportunity for IR theory to differentiate
# among institutional forms and recapture institutional
# Content: ...
# --------------------------------------------------------------------------------
# Section: We draw on the
# Content: ...
# --------------------------------------------------------------------------------
# Section: descriptive literature to accomplish
# Content: ...
# --------------------------------------------------------------------------------
# Section: regime theory has been rightly criticized for paying insufficient
# attention to issues of power and distribution in international
# Content: ...
# --------------------------------------------------------------------------------
# Section: We draw on realist
# considerations to supplement our institutionalist approach in this
# Content: ...
# --------------------------------------------------------------------------------
# Section: although regime theory has paid increasing attention to the role of ideas and norms in
# international politics
# Content: ...
# --------------------------------------------------------------------------------
# Section: Goldstein and Keohane
# Content: ...
# --------------------------------------------------------------------------------
# Section: it has only begun to incorporate
# these important
# Content: ...
# --------------------------------------------------------------------------------
# Section: we draw on constructivist theory for
# Content: ...
# --------------------------------------------------------------------------------
# Section: In
# Content: ...
# --------------------------------------------------------------------------------
# Section: we enrich our primarily rationalist approach with important insights from
# several different
# Content: ...
# --------------------------------------------------------------------------------
# Section: which we see as complementary rather than
# Content: ...
# --------------------------------------------------------------------------------
# Section: Decentralized cooperation theory takes as the problematic of international
# Content: ...
# --------------------------------------------------------------------------------
# Section: nance the existence of coordination and collaboration problems requiring collective
# action
# Content: ...
# --------------------------------------------------------------------------------
# Section: Oye
# Content: ...
# --------------------------------------------------------------------------------
# Section: Stein
# Content: ...
# --------------------------------------------------------------------------------
# Section: Snidal
# Content: ...
# --------------------------------------------------------------------------------
# Section: It assumes
# Content: ...
# --------------------------------------------------------------------------------
# Section: often depicted in
# game
# Content: ...
# --------------------------------------------------------------------------------
# Section: and analyzes how states cooperate in that spare context through
# strategies of reciprocity and other forms of
# Content: ...
# --------------------------------------------------------------------------------
# Section: The dependent variable is
# typically cooperation in the
# Content: ...
# --------------------------------------------------------------------------------
# Section: and much of the research in this tradition has been
# directed to disproving the realist assertion that cooperation in anarchy is
# Content: ...
# --------------------------------------------------------------------------------
# Section: There is no nuanced account of the forms of cooperation because the anarchy
# assumption makes 1Os and other institutions largely
# Content: ...
# --------------------------------------------------------------------------------
# Section: the strong
# assumptions that underlie the
# Content: ...
# --------------------------------------------------------------------------------
# Section: such as the need for
# Content: ...
# --------------------------------------------------------------------------------
# Section: quality
# Content: ...
# --------------------------------------------------------------------------------
# Section: suggest that cooperation is unlikely without an adequate institutional
# Content: ...
# --------------------------------------------------------------------------------
# Section: although the theory is only beginning to analyze that context
# Content: ...
# --------------------------------------------------------------------------------
# Section: Morrow
# Content: ...
# --------------------------------------------------------------------------------
# Section: For our
# This content downloaded from
# Content: ...
# --------------------------------------------------------------------------------
# Section: 122 on
# Content: ...
# --------------------------------------------------------------------------------
# Section: 26 Nov
# Content: ...
# --------------------------------------------------------------------------------
# Section: 45 UTC
# All use subject to
# Content: ...
# --------------------------------------------------------------------------------
# Section: terms
# Content: ...
# --------------------------------------------------------------------------------
# Section: FORMAL INTERNATIONAL ORGANIZATIONS
# Content: ...
# ...
# Section: MIT
# Content: ...
# --------------------------------------------------------------------------------
# Section: Standing
# Content: ...
# --------------------------------------------------------------------------------
# Section: Protecting foreign capital in the nineteenth and twentieth
# Content: ...
# --------------------------------------------------------------------------------
# Section: University of California
# Content: ...
# --------------------------------------------------------------------------------
# Section: Effective but cumbersome political
# Content: ...
# --------------------------------------------------------------------------------
# Section: International Organization
# Content: ...
# --------------------------------------------------------------------------------
# Section: Lisa
# Content: ...
# --------------------------------------------------------------------------------
# Section: Coercive
# Content: ...
# --------------------------------------------------------------------------------
# Section: Princeton University
# Content: ...
# --------------------------------------------------------------------------------
# Section: Connie
# Content: ...
# --------------------------------------------------------------------------------
# Section: Constructing the
# Content: ...
# --------------------------------------------------------------------------------
# Section: International organization andprescriptive
# Content: ...
# --------------------------------------------------------------------------------
# Section: The false promise of international
# Content: ...
# --------------------------------------------------------------------------------
# Section: International Security
# Content: ...
# --------------------------------------------------------------------------------
# Section: Paul
# Content: ...
# --------------------------------------------------------------------------------
# Section: Douglass
# Content: ...
# --------------------------------------------------------------------------------
# Section: and Barry
# Content: ...
# --------------------------------------------------------------------------------
# Section: The role of institutions in the revival
# of
# Content: ...
# --------------------------------------------------------------------------------
# Section: The law
# Content: ...
# --------------------------------------------------------------------------------
# Section: private
# Content: ...
# --------------------------------------------------------------------------------
# Section: and the champagne
# Content: ...
# --------------------------------------------------------------------------------
# Section: Economics and Politics
# Content: ...
# --------------------------------------------------------------------------------
# Section: Regime design
# Content: ...
# --------------------------------------------------------------------------------
# Section: Intentional oil pollution and treaty
# Content: ...
# --------------------------------------------------------------------------------
# Section: tional Organization
# Content: ...
# --------------------------------------------------------------------------------
# Section: Negotiating the Single European
# Content: ...
# --------------------------------------------------------------------------------
# Section: National interests and conventional
# statecraft in the European
# Content: ...
# --------------------------------------------------------------------------------
# Section: International Organization
# Content: ...
# --------------------------------------------------------------------------------
# Section: Politics among
# Content: ...
# --------------------------------------------------------------------------------
# Section: 4th
# Content: ...
# --------------------------------------------------------------------------------
# Section: New
# Content: ...
# --------------------------------------------------------------------------------
# Section: James
# Content: ...
# --------------------------------------------------------------------------------
# Section: The forms of international
# Content: ...
# --------------------------------------------------------------------------------
# Section: International Organization
# Content: ...
# --------------------------------------------------------------------------------
# Section: Gary
# Content: ...
# --------------------------------------------------------------------------------
# Section: and Steven
# Content: ...
# --------------------------------------------------------------------------------
# Section: lOs as
# Content: ...
# --------------------------------------------------------------------------------
# Section: International Organization
# Content: ...
# --------------------------------------------------------------------------------
# Section: and Richard
# Content: ...
# --------------------------------------------------------------------------------
# Section: An economic theory of
# Content: ...
# --------------------------------------------------------------------------------
# Section: Review of Economics and
# Statistics
# Content: ...
# --------------------------------------------------------------------------------
# Section: Kenneth
# Content: ...
# --------------------------------------------------------------------------------
# Section: Cooperation under
# Content: ...
# --------------------------------------------------------------------------------
# Section: Princeton University
# Content: ...
# --------------------------------------------------------------------------------
# Section: The rise and fall of international organization as a field of
# Content: ...
# --------------------------------------------------------------------------------
# Section: International
# Organization
# Content: ...
# --------------------------------------------------------------------------------
# Section: John
# Content: ...
# --------------------------------------------------------------------------------
# Section: and David
# Content: ...
# --------------------------------------------------------------------------------
# Section: In
# Content: ...
# --------------------------------------------------------------------------------
# Section: The third leg of the Kantian tripod for
# Content: ...
# --------------------------------------------------------------------------------
# Section: International organizations and militarized
# Content: ...
# --------------------------------------------------------------------------------
# Section: International Organization
# Content: ...
# --------------------------------------------------------------------------------
# Section: The World Bank and
# Content: ...
# --------------------------------------------------------------------------------
# Section: The plight of the
# Content: ...
# --------------------------------------------------------------------------------
# Section: s impoverished is still a
# major concern of the international
# Content: ...
# --------------------------------------------------------------------------------
# Section: American Journal of Economics and Sociology
# Content: ...
# --------------------------------------------------------------------------------
# Section: and Niels
# Content: ...
# --------------------------------------------------------------------------------
# Section: International institutional
# Content: ...
# --------------------------------------------------------------------------------
# Section: Unity within
# Content: ...
# --------------------------------------------------------------------------------
# Section: 3d
# Content: ...
# --------------------------------------------------------------------------------
# Section: Kluwer Law
# Content: ...
# --------------------------------------------------------------------------------
# Section: natural and open
# Content: ...
# --------------------------------------------------------------------------------
# Section: 3d
# Content: ...
# --------------------------------------------------------------------------------
# Section: Englewood
# Content: ...
# --------------------------------------------------------------------------------
# Section: Prentice
# Content: ...
# --------------------------------------------------------------------------------
# Section: Ibrahim
# Content: ...
# --------------------------------------------------------------------------------
# Section: The World Bank in a changing
# Content: ...
# --------------------------------------------------------------------------------
# Section: Kluwer
# Academic
# Content: ...
# --------------------------------------------------------------------------------
# Section: The World Bank in a changing
# Content: ...
# --------------------------------------------------------------------------------
# Section: Kluwer Law
# Content: ...
# --------------------------------------------------------------------------------
# Section: This content downloaded from
# Content: ...
# --------------------------------------------------------------------------------
# Section: 122 on
# Content: ...
# --------------------------------------------------------------------------------
# Section: 26 Nov
# Content: ...
# --------------------------------------------------------------------------------
# Section: 45 UTC
# All use subject to
# Content: ...
# --------------------------------------------------------------------------------
# Section: terms
# 32 JOURNAL OF CONFLICT RESOLUTION
# Content: ...
# --------------------------------------------------------------------------------
# Section: The limits of legitimation in international
# Content: ...
# --------------------------------------------------------------------------------
# Section: The Organization of American
# States and the Dominican
# Content: ...
# --------------------------------------------------------------------------------
# Section: International Organization
# Content: ...
# --------------------------------------------------------------------------------
# Section: Coordination versus
# Content: ...
# --------------------------------------------------------------------------------
# Section: Implications for international cooperation
# and
# Content: ...
# --------------------------------------------------------------------------------
# Section: American Political Science Review
# Content: ...
# --------------------------------------------------------------------------------
# Section: The game theory of international
# Content: ...
# --------------------------------------------------------------------------------
# Section: World Politics
# Content: ...
# --------------------------------------------------------------------------------
# Section: Political economy and international
# Content: ...
# --------------------------------------------------------------------------------
# Section: International Review of Law and Economics
# Content: ...
# --------------------------------------------------------------------------------
# Section: Cases and other materials on world
# Content: ...
# --------------------------------------------------------------------------------
# Section: Cases on United Nations
# Content: ...
# --------------------------------------------------------------------------------
# Section: 2d
# Content: ...
# --------------------------------------------------------------------------------
# Section: Coordination and
# Content: ...
# --------------------------------------------------------------------------------
# Section: Regimes in an anarchic
# Content: ...
# --------------------------------------------------------------------------------
# Section: In International
# Content: ...
# --------------------------------------------------------------------------------
# Section: edited by Stephen
# Content: ...
# --------------------------------------------------------------------------------
# Section: Cornell University
# Content: ...
# --------------------------------------------------------------------------------
# Section: Hic
# Content: ...
# --------------------------------------------------------------------------------
# Section: A critique of regime
# Content: ...
# --------------------------------------------------------------------------------
# Section: In International
# Content: ...
# --------------------------------------------------------------------------------
# Section: edited
# by Stephen
# Content: ...
# --------------------------------------------------------------------------------
# Section: Cornell University
# Content: ...
# --------------------------------------------------------------------------------
# Section: Joel
# Content: ...
# --------------------------------------------------------------------------------
# Section: The theory of the firm and the theory of international economic
# Content: ...
# --------------------------------------------------------------------------------
# Section: Toward comparative institutional
# Content: ...
# --------------------------------------------------------------------------------
# Section: Unpublished
# Content: ...
# --------------------------------------------------------------------------------
# Section: Vienna convention for the protection of the ozone
# Content: ...
# --------------------------------------------------------------------------------
# Section: International Legal Materials
# Content: ...
# --------------------------------------------------------------------------------
# Section: The European Bank for reconstruction and
# Content: ...
# --------------------------------------------------------------------------------
# Section: International Organization
# Content: ...
# --------------------------------------------------------------------------------
# Section: Anarchy is what states make of
# Content: ...
# --------------------------------------------------------------------------------
# Section: The social construction of power
# Content: ...
# --------------------------------------------------------------------------------
# Section: International
# Organization
# Content: ...
# --------------------------------------------------------------------------------
# Section: Constructing international
# Content: ...
# --------------------------------------------------------------------------------
# Section: International Security
# Content: ...
# --------------------------------------------------------------------------------
# Section: The economic institutions of
# Content: ...
# --------------------------------------------------------------------------------
# Section: New
# Content: ...
# --------------------------------------------------------------------------------
# Section: Free
# Content: ...
# --------------------------------------------------------------------------------
# Section: The mechanisms of
# Content: ...
# --------------------------------------------------------------------------------
# Section: Oxford University
# Content: ...
# --------------------------------------------------------------------------------
# Section: Beth
# Content: ...
# --------------------------------------------------------------------------------
# Section: and Robert
# Content: ...
# --------------------------------------------------------------------------------
# Section: Cooperation and governance in international
# Content: ...
# --------------------------------------------------------------------------------
# Section: Princeton University
# Content: ...
# --------------------------------------------------------------------------------
# Section: Oran
# Content: ...
# --------------------------------------------------------------------------------
# Section: International
# Content: ...
# --------------------------------------------------------------------------------
# Section: Cornell University
# Content: ...
# --------------------------------------------------------------------------------
# Section: This content downloaded from
# Content: ...
# --------------------------------------------------------------------------------
# Section: 122 on
# Content: ...
# --------------------------------------------------------------------------------
# Section: 26 Nov
# Content: ...
# --------------------------------------------------------------------------------
# Section: 45 UTC
# All use subject to
# Content: ...
# --------------------------------------------------------------------------------
# Section: terms
# Content: ...
# --------------------------------------------------------------------------------

# %%
# !pip install PyMuPDF scikit-learn transformers
# Out:
# Requirement already satisfied: PyMuPDF in /home/milo/anaconda3/lib/python3.12/site-packages (1.25.0)
# Requirement already satisfied: scikit-learn in /home/milo/anaconda3/lib/python3.12/site-packages (1.5.1)
# Requirement already satisfied: transformers in /home/milo/anaconda3/lib/python3.12/site-packages (4.46.3)
# Requirement already satisfied: numpy>=1.19.5 in /home/milo/anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.26.3)
# Requirement already satisfied: scipy>=1.6.0 in /home/milo/anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/milo/anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/milo/anaconda3/lib/python3.12/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: filelock in /home/milo/anaconda3/lib/python3.12/site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /home/milo/anaconda3/lib/python3.12/site-packages (from transformers) (0.26.2)
# Requirement already satisfied: packaging>=20.0 in /home/milo/anaconda3/lib/python3.12/site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/milo/anaconda3/lib/python3.12/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/milo/anaconda3/lib/python3.12/site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /home/milo/anaconda3/lib/python3.12/site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /home/milo/anaconda3/lib/python3.12/site-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in /home/milo/anaconda3/lib/python3.12/site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /home/milo/anaconda3/lib/python3.12/site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/milo/anaconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/milo/anaconda3/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/milo/anaconda3/lib/python3.12/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/milo/anaconda3/lib/python3.12/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/milo/anaconda3/lib/python3.12/site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/milo/anaconda3/lib/python3.12/site-packages (from requests->transformers) (2024.8.30)

# %%
import fitz  # PyMuPDF

def extract_text_with_metadata(pdf_path):
    document = fitz.open(pdf_path)
    text_data = []

    for page_num in range(len(document)):
        page = document.load_page(page_num)
        blocks = page.get_text("dict")["blocks"]  # Get text blocks with layout info
        
        for block in blocks:
            if block['type'] == 0:  # Text block
                for line in block['lines']:
                    line_text = line['spans'][0]['text']
                    font_size = line['spans'][0]['size']
                    font_bold = line['spans'][0].get('font', '').startswith('bold')
                    bbox = line['spans'][0]['bbox']  # Bounding box to track position

                    # Append the extracted text with metadata (font size, bold, bbox)
                    text_data.append({
                        "text": line_text,
                        "font_size": font_size,
                        "font_bold": font_bold,
                        "bbox": bbox
                    })
    
    return text_data

# %%
import re

def segment_text_into_sections(text_data):
    sections = []
    current_section = ""
    current_heading = "Introduction"  # Default heading
    prev_font_size = None

    for line in text_data:
        line_text = line["text"].strip()

        # Heuristic 1: Identify headings based on larger font sizes or bold text
        if line["font_size"] > 12 or line["font_bold"]:
            if current_section:  # If there's content from previous section, store it
                sections.append({"heading": current_heading, "content": current_section.strip()})
            
            # Set new section heading based on the text (e.g., if it's a title or heading)
            current_heading = line_text if re.match(r"[A-Za-z]+", line_text) else "Unknown Section"
            current_section = ""  # Reset content for new section

        else:
            current_section += " " + line_text  # Add line content to current section

    # Append the last section
    if current_section:
        sections.append({"heading": current_heading, "content": current_section.strip()})

    return sections

# %%
def clean_and_structure_sections(sections):
    cleaned_sections = []
    
    for section in sections:
        heading = section["heading"]
        content = section["content"]
        
        # Clean the content (e.g., remove extra spaces, newlines, etc.)
        content = re.sub(r'\s+', ' ', content).strip()
        
        cleaned_sections.append({
            "heading": heading,
            "content": content
        })

    return cleaned_sections

# %%
from transformers import BertTokenizer, BertForSequenceClassification
import torch

# Load pre-trained SciBERT model (or any model fine-tuned for scientific text)
tokenizer = BertTokenizer.from_pretrained("allenai/scibert_scivocab_cased")
model = BertForSequenceClassification.from_pretrained("allenai/scibert_scivocab_cased")

def extract_themes_with_scibert(sections):
    themes = []
    
    for section in sections:
        heading = section["heading"]
        content = section["content"]
        
        # Tokenize the content
        inputs = tokenizer(content, return_tensors="pt", truncation=True, padding=True, max_length=512)
        
        # Predict the theme or classification
        with torch.no_grad():
            outputs = model(**inputs)
            logits = outputs.logits
            predicted_class = torch.argmax(logits, dim=1).item()

        themes.append({
            "heading": heading,
            "predicted_theme": predicted_class
        })
    
    return themes
# Out:
# 2024-12-12 09:54:37.434280: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1733986477.664481   17908 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1733986477.729909   17908 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-12 09:54:38.320043: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# vocab.txt:   0%|          | 0.00/222k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/442M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at allenai/scibert_scivocab_cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
def process_pdf_for_themes(pdf_path):
    # Step 1: Extract text and metadata from the PDF
    text_data = extract_text_with_metadata(pdf_path)
    
    # Step 2: Segment text into sections based on heuristics
    sections = segment_text_into_sections(text_data)
    
    # Step 3: Clean and structure the text
    cleaned_sections = clean_and_structure_sections(sections)
    
    # Step 4: Analyze sections for themes using SciBERT
    themes = extract_themes_with_scibert(cleaned_sections)
    
    # Display results
    for theme in themes:
        print(f"Section: {theme['heading']}")
        print(f"Predicted Theme: {theme['predicted_theme']}")
        print("-" * 80)

# %%
# Example usage
pdf_path = pdf_path
result = process_pdf_for_themes(pdf_path)
# Out:
# Section: Introduction
# Predicted Theme: 0
# --------------------------------------------------------------------------------
# Section: International Organizations
# Predicted Theme: 1
# --------------------------------------------------------------------------------

# %%
result

# %%
import pandas as pd
import fitz  # PyMuPDF
import torch
from transformers import BertTokenizer, BertForSequenceClassification
import re
import os

# Initialize SciBERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained("allenai/scibert_scivocab_cased")
model = BertForSequenceClassification.from_pretrained("allenai/scibert_scivocab_cased")

def extract_text_with_metadata(pdf_path):
    document = fitz.open(pdf_path)
    text_data = []
    
    for page_num in range(len(document)):
        page = document.load_page(page_num)
        blocks = page.get_text("dict")["blocks"]  # Get text blocks with layout info
        
        for block in blocks:
            if block['type'] == 0:  # Text block
                for line in block['lines']:
                    line_text = line['spans'][0]['text']
                    font_size = line['spans'][0]['size']
                    font_bold = line['spans'][0].get('font', '').startswith('bold')
                    bbox = line['spans'][0]['bbox']  # Bounding box to track position
                    
                    # Append the extracted text with metadata
                    text_data.append({
                        "text": line_text,
                        "font_size": font_size,
                        "font_bold": font_bold,
                        "bbox": bbox
                    })
    
    return text_data

def segment_text_into_sections(text_data):
    sections = []
    current_section = ""
    current_heading = "Introduction"  # Default heading
    prev_font_size = None

    for line in text_data:
        line_text = line["text"].strip()
        
        # Heuristic 1: Identify headings based on larger font sizes or bold text
        if line["font_size"] > 12 or line["font_bold"]:
            if current_section:  # If there's content from the previous section, store it
                sections.append({"heading": current_heading, "content": current_section.strip()})
            
            # Set new section heading based on the text
            current_heading = line_text if re.match(r"[A-Za-z]+", line_text) else "Unknown Section"
            current_section = ""  # Reset content for new section

        else:
            current_section += " " + line_text  # Add line content to current section

    # Append the last section
    if current_section:
        sections.append({"heading": current_heading, "content": current_section.strip()})

    return sections

def clean_and_structure_sections(sections):
    cleaned_sections = []
    
    for section in sections:
        heading = section["heading"]
        content = section["content"]
        
        # Clean the content (e.g., remove extra spaces, newlines, etc.)
        content = re.sub(r'\s+', ' ', content).strip()
        
        cleaned_sections.append({
            "heading": heading,
            "content": content
        })

    return cleaned_sections

def extract_themes_with_scibert(sections):
    themes = []
    
    for section in sections:
        heading = section["heading"]
        content = section["content"]
        
        # Tokenize the content
        inputs = tokenizer(content, return_tensors="pt", truncation=True, padding=True, max_length=512)
        
        # Predict the theme or classification
        with torch.no_grad():
            outputs = model(**inputs)
            logits = outputs.logits
            predicted_class = torch.argmax(logits, dim=1).item()

        themes.append({
            "heading": heading,
            "predicted_theme": predicted_class
        })
    
    return themes

# Function to process the PDF and create a structured DataFrame
def process_pdf_for_themes(pdf_path):
    # Extract text and metadata from the PDF
    text_data = extract_text_with_metadata(pdf_path)
    
    # Segment the text into sections
    sections = segment_text_into_sections(text_data)
    
    # Clean and structure the sections
    cleaned_sections = clean_and_structure_sections(sections)
    
    # Extract themes using SciBERT
    themes = extract_themes_with_scibert(cleaned_sections)
    
    # Create a list of dictionaries for the DataFrame
    data = []
    
    for theme, section in zip(themes, cleaned_sections):
        journal_name = os.path.basename(pdf_path)  # Use the PDF filename as the journal name
        section_name = section["heading"]
        section_content = section["content"]
        predicted_theme = theme["predicted_theme"]
        
        data.append({
            "journal_name": journal_name,
            "section_name": section_name,
            "section_content": section_content,
            "predicted_theme": predicted_theme
        })
    
    # Convert the list of dictionaries into a DataFrame
    df = pd.DataFrame(data)
    
    return df
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at allenai/scibert_scivocab_cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Example usage
pdf_path = pdf_path # Replace with the actual path to your PDF
df = process_pdf_for_themes(pdf_path)

# Display the DataFrame
print(df.head())
# Out:
#                                         journal_name  \
# 0  Why states act through formal international or...
# 1  Why states act through formal international or...
#
#                   section_name  \
# 0                 Introduction
# 1  International Organizations
#
#                                      section_content  predicted_theme
# 0  Why States Act through Formal International Or...                1
# 1  KENNETH W. ABBOTT Graduate and International S...                1

# %%
df.head()
# Out:
#                                         journal_name  \
# 0  Why states act through formal international or...
# 1  Why states act through formal international or...
#
#                   section_name  \
# 0                 Introduction
# 1  International Organizations
#
#                                      section_content  predicted_theme
# 0  Why States Act through Formal International Or...                1
# 1  KENNETH W. ABBOTT Graduate and International S...                1

# %%
import pandas as pd
import fitz  # PyMuPDF
import torch
from transformers import BertTokenizer, BertForSequenceClassification
import re
import os

# Initialize SciBERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained("allenai/scibert_scivocab_cased")
model = BertForSequenceClassification.from_pretrained("allenai/scibert_scivocab_cased")

# Define a theme mapping for the model's output
theme_mapping = {
    0: "Methodology",
    1: "Results",
    2: "Introduction",
    3: "Conclusion",
    4: "Discussion",
    5: "Related Work",
    6: "Future Work",
    7: "Abstract"
}

def extract_text_with_metadata(pdf_path):
    document = fitz.open(pdf_path)
    text_data = []
    
    for page_num in range(len(document)):
        page = document.load_page(page_num)
        blocks = page.get_text("dict")["blocks"]  # Get text blocks with layout info
        
        for block in blocks:
            if block['type'] == 0:  # Text block
                for line in block['lines']:
                    line_text = line['spans'][0]['text']
                    font_size = line['spans'][0]['size']
                    font_bold = line['spans'][0].get('font', '').startswith('bold')
                    bbox = line['spans'][0]['bbox']  # Bounding box to track position
                    
                    # Append the extracted text with metadata
                    text_data.append({
                        "text": line_text,
                        "font_size": font_size,
                        "font_bold": font_bold,
                        "bbox": bbox
                    })
    
    return text_data

def segment_text_into_sections(text_data):
    sections = []
    current_section = ""
    current_heading = "Introduction"  # Default heading
    prev_font_size = None

    for line in text_data:
        line_text = line["text"].strip()
        
        # Heuristic 1: Identify headings based on larger font sizes or bold text
        if line["font_size"] > 12 or line["font_bold"]:
            if current_section:  # If there's content from the previous section, store it
                sections.append({"heading": current_heading, "content": current_section.strip()})
            
            # Set new section heading based on the text
            current_heading = line_text if re.match(r"[A-Za-z]+", line_text) else "Unknown Section"
            current_section = ""  # Reset content for new section

        else:
            current_section += " " + line_text  # Add line content to current section

    # Append the last section
    if current_section:
        sections.append({"heading": current_heading, "content": current_section.strip()})

    return sections

def clean_and_structure_sections(sections):
    cleaned_sections = []
    
    for section in sections:
        heading = section["heading"]
        content = section["content"]
        
        # Clean the content (e.g., remove extra spaces, newlines, etc.)
        content = re.sub(r'\s+', ' ', content).strip()
        
        cleaned_sections.append({
            "heading": heading,
            "content": content
        })

    return cleaned_sections

def extract_themes_with_scibert(sections):
    themes = []
    
    for section in sections:
        heading = section["heading"]
        content = section["content"]
        
        # Tokenize the content
        inputs = tokenizer(content, return_tensors="pt", truncation=True, padding=True, max_length=512)
        
        # Predict the theme or classification
        with torch.no_grad():
            outputs = model(**inputs)
            logits = outputs.logits
            predicted_class = torch.argmax(logits, dim=1).item()

        # Map the predicted class index to a human-readable theme
        predicted_theme = theme_mapping.get(predicted_class, "Unknown Theme")
        
        themes.append({
            "heading": heading,
            "predicted_theme_index": predicted_class,
            "predicted_theme": predicted_theme
        })
    
    return themes

# Function to process the PDF and create a structured DataFrame
def process_pdf_for_themes(pdf_path):
    # Extract text and metadata from the PDF
    text_data = extract_text_with_metadata(pdf_path)
    
    # Segment the text into sections
    sections = segment_text_into_sections(text_data)
    
    # Clean and structure the sections
    cleaned_sections = clean_and_structure_sections(sections)
    
    # Extract themes using SciBERT
    themes = extract_themes_with_scibert(cleaned_sections)
    
    # Create a list of dictionaries for the DataFrame
    data = []
    
    for theme, section in zip(themes, cleaned_sections):
        journal_name = os.path.basename(pdf_path)  # Use the PDF filename as the journal name
        section_name = section["heading"]
        section_content = section["content"]
        predicted_theme_index = theme["predicted_theme_index"]
        predicted_theme = theme["predicted_theme"]
        
        data.append({
            "journal_name": journal_name,
            "section_name": section_name,
            "section_content": section_content,
            "predicted_theme_index": predicted_theme_index,
            "predicted_theme": predicted_theme
        })
    
    # Convert the list of dictionaries into a DataFrame
    df = pd.DataFrame(data)
    
    return df
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at allenai/scibert_scivocab_cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Example usage
pdf_path = pdf_path  # Replace with the actual path to your PDF
df = process_pdf_for_themes(pdf_path)

# Display the DataFrame
df.head()
# Out:
#                                         journal_name  \
# 0  Why states act through formal international or...
# 1  Why states act through formal international or...
#
#                   section_name  \
# 0                 Introduction
# 1  International Organizations
#
#                                      section_content  predicted_theme_index  \
# 0  Why States Act through Formal International Or...                      0
# 1  KENNETH W. ABBOTT Graduate and International S...                      0
#
#   predicted_theme
# 0     Methodology
# 1     Methodology

# %%
import os
import pandas as pd
import fitz  # PyMuPDF
import torch
from transformers import BertTokenizer, BertForSequenceClassification
import re

# Initialize SciBERT tokenizer and model
tokenizer = BertTokenizer.from_pretrained("allenai/scibert_scivocab_cased")
model = BertForSequenceClassification.from_pretrained("allenai/scibert_scivocab_cased")

# Define a theme mapping for the model's output
theme_mapping = {
    0: "Methodology",
    1: "Results",
    2: "Introduction",
    3: "Conclusion",
    4: "Discussion",
    5: "Related Work",
    6: "Future Work",
    7: "Abstract"
}

def extract_text_with_metadata(pdf_path):
    document = fitz.open(pdf_path)
    text_data = []
    
    for page_num in range(len(document)):
        page = document.load_page(page_num)
        blocks = page.get_text("dict")["blocks"]  # Get text blocks with layout info
        
        for block in blocks:
            if block['type'] == 0:  # Text block
                for line in block['lines']:
                    line_text = line['spans'][0]['text']
                    font_size = line['spans'][0]['size']
                    font_bold = line['spans'][0].get('font', '').startswith('bold')
                    bbox = line['spans'][0]['bbox']  # Bounding box to track position
                    
                    # Append the extracted text with metadata
                    text_data.append({
                        "text": line_text,
                        "font_size": font_size,
                        "font_bold": font_bold,
                        "bbox": bbox
                    })
    
    return text_data

def segment_text_into_sections(text_data):
    sections = []
    current_section = ""
    current_heading = "Introduction"  # Default heading
    prev_font_size = None

    for line in text_data:
        line_text = line["text"].strip()
        
        # Heuristic 1: Identify headings based on larger font sizes or bold text
        if line["font_size"] > 12 or line["font_bold"]:
            if current_section:  # If there's content from the previous section, store it
                sections.append({"heading": current_heading, "content": current_section.strip()})
            
            # Set new section heading based on the text
            current_heading = line_text if re.match(r"[A-Za-z]+", line_text) else "Unknown Section"
            current_section = ""  # Reset content for new section

        else:
            current_section += " " + line_text  # Add line content to current section

    # Append the last section
    if current_section:
        sections.append({"heading": current_heading, "content": current_section.strip()})

    return sections

def clean_and_structure_sections(sections):
    cleaned_sections = []
    
    for section in sections:
        heading = section["heading"]
        content = section["content"]
        
        # Clean the content (e.g., remove extra spaces, newlines, etc.)
        content = re.sub(r'\s+', ' ', content).strip()
        
        cleaned_sections.append({
            "heading": heading,
            "content": content
        })

    return cleaned_sections

def extract_themes_with_scibert(sections):
    themes = []
    
    for section in sections:
        heading = section["heading"]
        content = section["content"]
        
        # Tokenize the content
        inputs = tokenizer(content, return_tensors="pt", truncation=True, padding=True, max_length=512)
        
        # Predict the theme or classification
        with torch.no_grad():
            outputs = model(**inputs)
            logits = outputs.logits
            predicted_class = torch.argmax(logits, dim=1).item()

        # Map the predicted class index to a human-readable theme
        predicted_theme = theme_mapping.get(predicted_class, "Unknown Theme")
        
        themes.append({
            "heading": heading,
            "predicted_theme_index": predicted_class,
            "predicted_theme": predicted_theme
        })
    
    return themes

def process_pdf_for_themes(pdf_path):
    # Extract text and metadata from the PDF
    text_data = extract_text_with_metadata(pdf_path)
    
    # Segment the text into sections
    sections = segment_text_into_sections(text_data)
    
    # Clean and structure the sections
    cleaned_sections = clean_and_structure_sections(sections)
    
    # Extract themes using SciBERT
    themes = extract_themes_with_scibert(cleaned_sections)
    
    # Create a list of dictionaries for the DataFrame
    data = []
    
    for theme, section in zip(themes, cleaned_sections):
        journal_name = os.path.basename(pdf_path)  # Use the PDF filename as the journal name
        section_name = section["heading"]
        section_content = section["content"]
        predicted_theme_index = theme["predicted_theme_index"]
        predicted_theme = theme["predicted_theme"]
        
        data.append({
            "journal_name": journal_name,
            "section_name": section_name,
            "section_content": section_content,
            "predicted_theme_index": predicted_theme_index,
            "predicted_theme": predicted_theme
        })
    
    # Convert the list of dictionaries into a DataFrame
    df = pd.DataFrame(data)
    
    return df

# Function to process all PDFs in the folder and combine them into a single DataFrame
def process_pdfs_in_folder(pdf_folder_path):
    all_data = []

    # Loop through all PDF files in the folder
    for pdf_file in os.listdir(pdf_folder_path):
        if pdf_file.endswith('.pdf'):
            pdf_path = os.path.join(pdf_folder_path, pdf_file)
            df = process_pdf_for_themes(pdf_path)
            all_data.append(df)
    
    # Concatenate all individual DataFrames into one
    combined_df = pd.concat(all_data, ignore_index=True)
    return combined_df

# Example usage
pdf_folder_path = '../Data/Attribute_Papers/'  # Path to your folder containing PDFs
final_df = process_pdfs_in_folder(pdf_folder_path)

# # Display the final DataFrame
# print(final_df.head())

# # Optionally, save the result to a CSV or Excel file
# final_df.to_csv('extracted_sections_with_themes.csv', index=False)
# final_df.to_excel('extracted_sections_with_themes.xlsx', index=False)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at allenai/scibert_scivocab_cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 872 entries, 0 to 871
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   journal_name           872 non-null    object
#  1   section_name           872 non-null    object
#  2   section_content        872 non-null    object
#  3   predicted_theme_index  872 non-null    int64
#  4   predicted_theme        872 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 34.2+ KB

# %%
final_df.head()
# Out:
#                                         journal_name  \
# 0  International Organizations and Implementation...
# 1  International Organizations and Implementation...
# 2  Critical Choices_The United Nations_Networks a...
# 3  Critical Choices_The United Nations_Networks a...
# 4  Critical Choices_The United Nations_Networks a...
#
#                                       section_name  \
# 0                                     Introduction
# 1  Jutta Joachim, Bob Reinalda and Bertjan Verbeek
# 2                                         ADVISORY
# 3                                          CHOICES
# 4                                         CONTENTS
#
#                                      section_content  predicted_theme_index  \
# 0  Enforcers, managers, authorities? Internationa...                      0
# 1  1 Introduction This edited volume has explored...                      0
# 2  Tunku Former Commonwealth Secretariat and Tran...                      0
# 3  WOLFGANG AND with JAN THORSTEN BENNER, BETH AN...                      0
# 4  Foreword vii Preface ix Executive xi Origins x...                      1
#
#   predicted_theme
# 0     Methodology
# 1     Methodology
# 2     Methodology
# 3     Methodology
# 4         Results
